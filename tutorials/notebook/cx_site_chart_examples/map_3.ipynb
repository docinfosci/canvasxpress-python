# %% [markdown]
# # Example: CanvasXpress map Chart No. 3
#
# This example page demonstrates how to, using the Python package, create a chart that matches the CanvasXpress online example located at:
#
# https://www.canvasxpress.org/examples/map-3.html
#
# This example is generated using the reproducible JSON obtained from the above page and the `canvasxpress.util.generator.generate_canvasxpress_code_from_json_file()` function.
#
# Everything required for the chart to render is included in the code below.  Simply run the code block.

# %%
from canvasxpress.canvas import CanvasXpress 
from canvasxpress.js.collection import CXEvents 
from canvasxpress.render.jupyter import CXNoteBook 

cx = CanvasXpress(
    render_to="map31",
    data={"y": {"vars": ["Aruba", "Afghanistan", "Angola", "Anguilla", "Albania", "Aland Islands", "Andorra", "United Arab Emirates", "Argentina", "Armenia", "American Samoa", "Antarctica", "Australia", "French Southern Territories", "Antigua and Barbuda", "Australia2", "Austria", "Azerbaijan", "Burundi", "Belgium", "Benin", "Burkina Faso", "Bangladesh", "Bulgaria", "Bahrain", "Bahamas", "Bosnia and Herzegovina", "Saint-Barth\u00e9lemy", "Belarus", "Belize", "Bermuda", "Bolivia", "Brazil", "Barbados", "Brunei Darussalam", "Bhutan", "Botswana", "Central African Republic", "Canada", "Switzerland", "Chile", "China", "C\u00f4te d'Ivoire", "Cameroon", "Democratic Republic of the Congo", "Congo (Brazzaville)", "Cook Islands", "Colombia", "Comoros", "Cape Verde", "Costa Rica", "Cuba", "Curacao", "Cayman Islands", "Missing Name 54", "Cyprus", "Czech Republic", "Germany", "Djibouti", "Dominica", "Denmark", "Dominican Republic", "Algeria", "Ecuador", "Egypt", "Eritrea", "Spain", "Estonia", "Ethiopia", "Finland", "Fiji", "Falkland Islands (Malvinas)", "France", "Faroe Islands", "Micronesia", "Gabon", "United Kingdom", "Georgia", "Guernsey", "Ghana", "Guinea", "Gambia", "Guinea-Bissau", "Equatorial Guinea", "Greece", "Grenada", "Greenland", "Guatemala", "Guam", "Guyana", "Hong Kong", "Heard Island and Mcdonald Islands", "Honduras", "Croatia", "Haiti", "Hungary", "Indonesia", "Isle of Man", "India", "Missing Name 99", "British Indian Ocean Territory", "Ireland", "Islamic Republic of Iran", "Iraq", "Iceland", "Israel", "Italy", "Jamaica", "Jersey", "Jordan", "Japan", "Missing Name 111", "Kazakhstan", "Kenya", "Kyrgyzstan", "Cambodia", "Kiribati", "Saint Kitts and Nevis", "Korea", "Missing Name 119", "Kuwait", "Lao PDR", "Lebanon", "Liberia", "Libya", "Saint Lucia", "Liechtenstein", "Sri Lanka", "Lesotho", "Lithuania", "Luxembourg", "Latvia", "Macao", "Saint-Martin (French part)", "Morocco", "Monaco", "Moldova", "Madagascar", "Maldives", "Mexico", "Marshall Islands", "Macedonia", "Mali", "Malta", "Myanmar", "Montenegro", "Mongolia", "Northern Mariana Islands", "Mozambique", "Mauritania", "Montserrat", "Mauritius", "Malawi", "Malaysia", "Namibia", "New Caledonia", "Niger", "Norfolk Island", "Nigeria",
", "ATG", None, "AUT", "AZE", "BDI", "BEL", "BEN", "BFA", "BGD", "BGR", "BHR", "BHS", "BIH", None, "BLR", "BLZ", "BMU", "BOL", "BRA", "BRB", "BRN", "BTN", "BWA", "CAF", "CAN", "CHE", "CHL", "CHN", None, "CMR", None, None, "COK", "COL", "COM", None, "CRI", "CUB", None, "CYM", None, "CYP", "CZE", "DEU", "DJI", "DMA", "DNK", "DOM", "DZA", "ECU", "EGY", "ERI", "ESP", "EST", "ETH", "FIN", "FJI", None, "FRA", "FRO", "FSM", "GAB", None, "GA", "GGY", "GHA", "GIN", "GMB", "GNB", "GNQ", "GRE", "GRD", "GRL", "GTM", "GUM", "GUY", "HKG", None, "HND", "HRV", "HTI", "HUN", "IDN", "IMN", "IND", None, "IOT", "IRL", None, "IRQ", "ISL", "ISR", "ITA", "JAM", "JEY", "JOR", "JPN", None, "KAZ", "KEN", "KGZ", "KHM", "KIR", "KNA", None, None, "KWT", None, "LBN", "LBR", "LBY", "LCA", "LIE", "LKA", "LSO", "LTU", "LUX", "LVA", "MAC", None, "MAR", "MCO", "MDA", "MDG", "MDV", "MEX", "MHL", "MKD", "MLI", "MLT", "MMR", "MNE", "MNG", None, "MOZ", "MRT", "MSR", "MUS", "MWI", "MYS", "NAM", "NCL", "NER", "NFK", "NGA", "NIC", "NIU", "NLD", "NOR", "NPL", "NRU", "NZL", "OMN", "PAK", "PAN", "PCN", "PER", "PHL", "PLW", "PNG", "POL", "PR", None, "PRT", "PRY", None, "PYF", "QAT", "ROU", "RUS", "RWA", "ESH", "SAU", "SDN", "SSD", "SEN", "SGP", "SGS", "SHN", "SLB", "SLE", "SLV", "SMR", None, "SOM", "SPM", "SRB", "STP", "SUR", "SVK", "SVN", "SWE", "SWZ", None, "SYC", None, "TCA", "TCD", "TGO", "THA", "TJK", "TKM", "TLS", "TON", "TTO", "TUN", "TUR", "TWN", "TZA", "UGA", "UKR", "URY", None, "UZB", None, "VEN", None, None, None, "VUT", None, "WSM", "YEM", "ZAF", "ZMB", "ZWE"], "name": [None, "Afghanistan", "Angola", None, "Albania", None, None, "United Arab Emirates", "Argentina", "Armenia", None, None, "Australia", None, None, None, "Austria", "Azerbaijan", "Burundi", "Belgium", "Benin", "Burkina Faso", "Bangladesh", "Bulgaria", None, None, "Bosnia and Herzegovina", None, "Belarus", "Belize", "Bermuda", "Bolivia", "Brazil", None, None, "Bhutan", "Botswana", "Central African Republic", "Canada", "Switzerland", "Chile", "China", None, "Cameroon", None, None, None, "Colombia", None, None, "Costa Rica", "Cuba", None, None, None, "Cyprus", "Czech Republic", "Germany", "Djibouti", None, "Denmark", "Dominican Republic", "Algeria", "Ecuador", "Egypt", "Eritrea", "Spain", "Estonia", "Ethiopia", "Finland", "Fiji", None, "France", None, None, "Gabon", None, "Georgia", None, "Ghana", "Guinea", "Gambia", None, "Equatorial Guinea", "Greece", None, "Greenland", "Guatemala", None, "Guyana", None, None, "Honduras", "Croatia", "Haiti", "Hungary", "Indonesia", None, "India", None, None, "Ireland", None, "Iraq", "Iceland", "Israel", "Italy", "Jamaica", None, "Jordan", "Japan", None, "Kazakhstan", "Kenya", "Kyrgyzstan", "Cambodia", None, None, None, None, "Kuwait", None, "Lebanon", "Liberia", "Libya", None, None, "Sri Lanka", "Lesotho", "Lithuania", "Luxembourg", "Latvia", None, None, "Morocco", None, "Moldova", "Madagascar", None, "Mexico", None, "Macedonia", "Mali", "Malta", "Myanmar", "Montenegro", "Mongolia", None, "Mozambique", "Mauritania", None, None, "Malawi", "Malaysia", "Namibia", "New Caledonia", "Niger", None, "Nigeria", "Nicaragua", None, "Netherlands", "Norway", "Nepal", None, "New Zealand", "Oman", "Pakistan", "Panama", None, "Peru", "Philippines", None, "Papua New Guinea", "Poland", "Puerto Rico", None, "Portugal", "Paraguay", None, None, "Qatar", "Romania", None, "Rwanda", "Western Sahara", "Saudi Arabia", "Sudan", "South Sudan", "Senegal", None, None, None, "Solomon Islands", "Sierra Leone", "El Salvador", None, None, "Somalia", None, None, None, "Suriname", "Slovakia", "Slovenia", "Sweden", "Swaziland", None, None, None, None, "Chad", "Togo", "Thailand", "Tajikistan", "Turkmenistan", None, None, "Trinidad and Tobago", "Tunisia", "Turkey", "Taiwan", None, "Uganda", "Ukraine", "Uruguay", None, "Uzbekistan", None, "Venezuela", None, None, None, "Vanuatu", None, None, "Yemen", "South Africa", "Zambia", "Zimbabwe"]}},
    config={"colorBy": "id", "decorations": {"connections": [{"source": [40.7, "-74"], "target": [37.7, "-122"], "type": "spline", "color": "red"}, {"color": "red", "target": [25.7, -80.1], "source": [40.7, "-74"], "type": "spline"}, {"target": [25.7, -80.1], "source": [37.7, "-122"], "type": "splineDashed", "color": "red"}], "marker": [{"color": "blue", "coords": [40.7, "-74"], "size": 5, "label": "New York", "shape": "teardrop"}, {"shape": "teardrop", "size": 5, "label": "San Francisco", "color": "blue", "coords": [37.7, "-122"]}, {"shape": "teardrop", "coords": [25.7, -80.1], "color": "blue", "size": 5, "label": "Miami"}, {"coords": [41.8, -87.6], "color": "green", "label": "Chicago", "size": 4, "shape": "circle"}, {"shape": "circle", "coords": [36.1, -115.1], "color": "green", "label": "Las Vegas", "size": 3}, {"shape": "star", "color": "black", "coords": [42.3, "-71"], "label": "Boston", "size": 6}]}, "graphType": "Map", "mapConfig": {"center": [34.7, -96.1], "zoom": 3.2}, "mapId": "colorCountries", "showLegend": False, "topoJSON": "https://www.canvasxpress.org/data/world.geo.json", "remoteTransitionEffect": "none", "skipRender": False},
    width=603,
    height=600,
    events=CXEvents(),
    after_render=[],
    other_init_params={
        "version": 36.4,
        "events": False,
        "info": False,
        "afterRenderInit": False,
        "noValidate": True
    }
)

display = CXNoteBook(cx) 
display.render(output_file="map_3.html")
