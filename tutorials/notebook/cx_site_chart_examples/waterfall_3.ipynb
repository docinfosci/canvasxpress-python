# %% [markdown]
# # Example: CanvasXpress waterfall Chart No. 3
#
# This example page demonstrates how to, using the Python package, create a chart that matches the CanvasXpress online example located at:
#
# https://www.canvasxpress.org/examples/waterfall-3.html
#
# This example is generated using the reproducible JSON obtained from the above page and the `canvasxpress.util.generator.generate_canvasxpress_code_from_json_file()` function.
#
# Everything required for the chart to render is included in the code below.  Simply run the code block.

# %%
from canvasxpress.canvas import CanvasXpress 
from canvasxpress.js.collection import CXEvents 
from canvasxpress.render.jupyter import CXNoteBook 

cx = CanvasXpress(
    render_to="waterfall3",
    data={"y": {"vars": ["Shrinkage"], "smps": ["1001", "1002", "1003", "1004", "1005", "1006", "1007", "1008", "1009", "1010", "1011", "1012", "1013", "1014", "1015", "1016"], "data": [[115, 75, 39, 23, 22, 15, 12, 10, 10, 10, 5, 4, 2, -8, -11, -31]]}, "x": {"Tissue": ["Pancreas", "Pancreas", "Pancreas", "Colrectal", "Breast", "Colrectal", "Colrectal", "Colrectal", "Billiary tract", "Colrectal", "Esophagus", "Billiary tract", "Billiary tract", "Billiary tract", "Colrectal", "Billiary tract"], "Status": ["PD", "PD", "PD", "PD", "PD", "PD", "SD", "PD", "PD", "PD", "PD", "PD", "SD", "SD", "SD", "PR"]}},
    config={"colorBy": "Tissue", "colorScheme": "NEJM", "graphOrientation": "vertical", "graphType": "Bar", "legendInside": True, "legendKeyBackgroundBorderColor": "rgba(255,255,255,0.0)", "legendKeyBackgroundColor": "rgba(255,255,255,0.0)", "legendPosition": "topRight", "showSampleNames": False, "smpOverlayProperties": {"Status": {"scheme": "White", "position": "bottom", "type": "Default", "color": "rgb(188,60,41)", "spectrum": ["rgb(69,117,180)", "rgb(145,191,219)", "rgb(224,243,248)", "rgb(255,255,191)", "rgb(254,224,144)", "rgb(252,141,89)", "rgb(215,48,39)"], "showLegend": True, "showName": True, "showBox": True, "rotate": False}}, "smpOverlays": ["Status"], "title": "Clinical Trial", "xAxis2Show": False, "xAxisTitle": "Best tumor shrinkage (%)"},
    width=600,
    height=600,
    events=CXEvents(),
    after_render=[],
    other_init_params={
        "version": 40.6,
        "events": False,
        "info": False,
        "afterRenderInit": False,
        "noValidate": True
    }
)

display = CXNoteBook(cx) 
display.render(output_file="waterfall_3.html")
