# %% [markdown]
# # Example: CanvasXpress network Chart No. 4
#
# This example page demonstrates how to, using the Python package, create a chart that matches the CanvasXpress online example located at:
#
# https://www.canvasxpress.org/examples/network-4.html
#
# This example is generated using the reproducible JSON obtained from the above page and the `canvasxpress.util.generator.generate_canvasxpress_code_from_json_file()` function.
#
# Everything required for the chart to render is included in the code below.  Simply run the code block.

# %%
from canvasxpress.canvas import CanvasXpress 
from canvasxpress.js.collection import CXEvents 
from canvasxpress.render.jupyter import CXNoteBook 

cx = CanvasXpress(
    render_to="network4",
    data={
        "nodes": [
            {
                "id": "Gene1",
                "color": "rgb(255,0,0)",
                "shape": "square",
                "layout": {
                    "angle": 0,
                    "children": [
                        "Gene2",
                        "Gene3",
                        "Gene4",
                        "Gene5"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene1",
                            "id2": "Gene2",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene1",
                            "id2": "Gene3",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene1",
                            "id2": "Gene4",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene1",
                            "id2": "Gene5",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 294.6500000000001,
                        "y": 280.29999999999984,
                        "z": 0,
                        "r": 0,
                        "a": 0
                    },
                    "level": 0,
                    "mass": 2.333333333333333,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [],
                    "order": 15,
                    "parent": False,
                    "position": {
                        "x": 294.65,
                        "y": 280.3,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 4,
                "x": 294.65,
                "y": 280.3,
                "z": 0,
                "community": 0,
                "communityColor": "rgb(254,41,108)"
            },
            {
                "id": "Gene2",
                "color": "rgb(255,0,0)",
                "shape": "square",
                "layout": {
                    "angle": 76.5,
                    "children": [
                        "Gene7",
                        "Gene8",
                        "Gene1"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene1",
                            "id2": "Gene2",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene2",
                            "id2": "Gene7",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene2",
                            "id2": "Gene8",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 329.0423382300712,
                        "y": 423.5543985225877,
                        "z": 0,
                        "r": 147.32499999999996,
                        "a": 76.5
                    },
                    "level": 1,
                    "mass": 2,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene1"
                    ],
                    "order": 16,
                    "parent": "Gene1",
                    "position": {
                        "x": 328.6741835525266,
                        "y": 422.0209239288533,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 3,
                "x": 328.6741835525266,
                "y": 422.0209239288533,
                "z": 0,
                "community": 1,
                "communityColor": "rgb(72,126,182)"
            },
            {
                "id": "Gene3",
                "color": "rgb(255,0,0)",
                "shape": "square",
                "layout": {
                    "angle": 198,
                    "children": [
                        "SNP1",
                        "SNP2",
                        "Gene1"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene1",
                            "id2": "Gene3",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene3",
                            "id2": "SNP1",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene3",
                            "id2": "SNP2",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 154.5355987368165,
                        "y": 234.77407130371068,
                        "z": 0,
                        "r": 147.32500000000005,
                        "a": 198
                    },
                    "level": 1,
                    "mass": 2,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene1"
                    ],
                    "order": 17,
                    "parent": "Gene1",
                    "position": {
                        "x": 156.0354610570615,
                        "y": 235.26140611319602,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 3,
                "x": 156.0354610570615,
                "y": 235.26140611319602,
                "z": 0,
                "community": 2,
                "communityColor": "rgb(167,206,49)"
            },
            {
                "id": "Gene4",
                "color": "rgb(255,0,0)",
                "shape": "square",
                "layout": {
                    "angle": 288,
                    "children": [
                        "SNP3",
                        "Gene1"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene4",
                            "id2": "SNP3",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene1",
                            "id2": "Gene4",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 340.17592869628896,
                        "y": 140.1855987368166,
                        "z": 0,
                        "r": 147.32499999999987,
                        "a": 288
                    },
                    "level": 1,
                    "mass": 1.6666666666666665,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene1"
                    ],
                    "order": 18,
                    "parent": "Gene1",
                    "position": {
                        "x": 339.6885938868038,
                        "y": 141.6854610570617,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 2,
                "x": 339.6885938868038,
                "y": 141.6854610570617,
                "z": 0,
                "community": 3,
                "communityColor": "rgb(248,204,3)"
            },
            {
                "id": "Gene5",
                "color": "rgb(255,0,0)",
                "shape": "square",
                "layout": {
                    "angle": 324,
                    "children": [
                        "Gene1"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene1",
                            "id2": "Gene5",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 413.83842869628904,
                        "y": 193.70453770601142,
                        "z": 0,
                        "r": 147.32499999999993,
                        "a": 324
                    },
                    "level": 1,
                    "mass": 1.3333333333333333,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene1"
                    ],
                    "order": 19,
                    "parent": "Gene1",
                    "position": {
                        "x": 412.5625696011558,
                        "y": 194.63150359836814,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 1,
                "x": 412.5625696011558,
                "y": 194.63150359836814,
                "z": 0,
                "community": 0,
                "communityColor": "rgb(254,41,108)"
            },
            {
                "id": "Gene6",
                "color": "rgb(255,0,0)",
                "shape": "square",
                "layout": {
                    "angle": 18,
                    "children": [
                        "SNP4",
                        "SNP5",
                        "SNP7"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene6",
                            "id2": "SNP4",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene6",
                            "id2": "SNP5",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "SNP7",
                            "id2": "Gene6",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 995.2220063159175,
                        "y": 507.9296434814456,
                        "z": 0,
                        "r": 736.625,
                        "a": 18
                    },
                    "level": 5,
                    "mass": 2,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [],
                    "order": 20,
                    "parent": "SNP7",
                    "position": {
                        "x": 987.7226947146921,
                        "y": 505.49296943401964,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 3,
                "x": 987.7226947146921,
                "y": 505.49296943401964,
                "z": 0,
                "community": 4,
                "communityColor": "rgb(255,140,2)"
            },
            {
                "id": "Gene7",
                "color": "rgb(255,0,0)",
                "shape": "square",
                "layout": {
                    "angle": 45,
                    "children": [
                        "SNP6",
                        "Gene2"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene2",
                            "id2": "Gene7",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene7",
                            "id2": "SNP6",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 502.99901307661605,
                        "y": 488.64901307661603,
                        "z": 0,
                        "r": 294.64999999999975,
                        "a": 45
                    },
                    "level": 2,
                    "mass": 1.6666666666666665,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene2"
                    ],
                    "order": 21,
                    "parent": "Gene2",
                    "position": {
                        "x": 500.76872959856803,
                        "y": 486.41872959856806,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 2,
                "x": 500.76872959856803,
                "y": 486.41872959856806,
                "z": 0,
                "community": 1,
                "communityColor": "rgb(72,126,182)"
            },
            {
                "id": "Gene8",
                "color": "rgb(255,0,0)",
                "shape": "square",
                "layout": {
                    "angle": 108,
                    "children": [
                        "Gene2"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene2",
                            "id2": "Gene8",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 203.5981426074218,
                        "y": 560.528802526367,
                        "z": 0,
                        "r": 294.65,
                        "a": 108
                    },
                    "level": 2,
                    "mass": 1.3333333333333333,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene2"
                    ],
                    "order": 22,
                    "parent": "Gene2",
                    "position": {
                        "x": 204.57281222639216,
                        "y": 557.5290778858769,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 1,
                "x": 204.57281222639216,
                "y": 557.5290778858769,
                "z": 0,
                "community": 1,
                "communityColor": "rgb(72,126,182)"
            },
            {
                "id": "SNP1",
                "color": "rgb(0,255,0)",
                "shape": "sphere",
                "layout": {
                    "angle": 162,
                    "children": [
                        "PH1",
                        "Gene3"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "SNP1",
                            "id2": "PH1",
                            "color": "rgb(51,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene3",
                            "id2": "SNP1",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 14.421197473633129,
                        "y": 371.35185739257827,
                        "z": 0,
                        "r": 294.64999999999986,
                        "a": 162
                    },
                    "level": 2,
                    "mass": 1.6666666666666665,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene3"
                    ],
                    "order": 23,
                    "parent": "Gene3",
                    "position": {
                        "x": 17.420922114123243,
                        "y": 370.37718777360783,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 2,
                "x": 17.420922114123243,
                "y": 370.37718777360783,
                "z": 0,
                "community": 2,
                "communityColor": "rgb(167,206,49)"
            },
            {
                "id": "SNP2",
                "color": "rgb(0,255,0)",
                "shape": "sphere",
                "layout": {
                    "angle": 234,
                    "children": [
                        "PH2",
                        "Gene3"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene3",
                            "id2": "SNP2",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "SNP2",
                            "id2": "PH2",
                            "color": "rgb(153,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 121.45907541202268,
                        "y": 41.92314260742194,
                        "z": 0,
                        "r": 294.6499999999999,
                        "a": 234
                    },
                    "level": 2,
                    "mass": 1.6666666666666665,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene3"
                    ],
                    "order": 24,
                    "parent": "Gene3",
                    "position": {
                        "x": 123.31300719673624,
                        "y": 44.47486079768831,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 2,
                "x": 123.31300719673624,
                "y": 44.47486079768831,
                "z": 0,
                "community": 5,
                "communityColor": "rgb(105,150,150)"
            },
            {
                "id": "SNP3",
                "color": "rgb(0,255,0)",
                "shape": "sphere",
                "layout": {
                    "angle": 288,
                    "children": [
                        "PH3",
                        "Gene4"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene4",
                            "id2": "SNP3",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "SNP3",
                            "id2": "PH3",
                            "color": "rgb(51,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 385.70185739257806,
                        "y": 0.0711974736331058,
                        "z": 0,
                        "r": 294.64999999999986,
                        "a": 288
                    },
                    "level": 2,
                    "mass": 1.6666666666666665,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene4"
                    ],
                    "order": 0,
                    "parent": "Gene4",
                    "position": {
                        "x": 384.72718777360774,
                        "y": 3.0709221141232774,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 2,
                "x": 384.72718777360774,
                "y": 3.0709221141232774,
                "z": 0,
                "community": 3,
                "communityColor": "rgb(248,204,3)"
            },
            {
                "id": "SNP4",
                "color": "rgb(0,255,0)",
                "shape": "sphere",
                "layout": {
                    "angle": 0,
                    "children": [
                        "PH4",
                        "Gene6"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "SNP4",
                            "id2": "PH4",
                            "color": "rgb(51,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "Gene6",
                            "id2": "SNP4",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 1178.5999999999997,
                        "y": 280.3,
                        "z": 0,
                        "r": 883.9499999999997,
                        "a": 0
                    },
                    "level": 6,
                    "mass": 1.6666666666666665,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene6"
                    ],
                    "order": 1,
                    "parent": "Gene6",
                    "position": {
                        "x": 1169.1377085722233,
                        "y": 280.3,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 2,
                "x": 1169.1377085722233,
                "y": 280.3,
                "z": 0,
                "community": 6,
                "communityColor": "rgb(183,120,68)"
            },
            {
                "id": "SNP5",
                "color": "rgb(0,255,0)",
                "shape": "sphere",
                "layout": {
                    "angle": 36,
                    "children": [
                        "Gene6"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene6",
                            "id2": "SNP5",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 1009.7805721777347,
                        "y": 799.8727737639316,
                        "z": 0,
                        "r": 883.9499999999999,
                        "a": 36
                    },
                    "level": 6,
                    "mass": 1.3333333333333333,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene6"
                    ],
                    "order": 2,
                    "parent": "Gene6",
                    "position": {
                        "x": 1002.1254176069353,
                        "y": 794.3109784097912,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 1,
                "x": 1002.1254176069353,
                "y": 794.3109784097912,
                "z": 0,
                "community": 4,
                "communityColor": "rgb(255,140,2)"
            },
            {
                "id": "SNP6",
                "color": "rgb(0,255,0)",
                "shape": "sphere",
                "layout": {
                    "angle": 45,
                    "children": [
                        "SNP7",
                        "SNP8",
                        "Gene7"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "Gene7",
                            "id2": "SNP6",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "SNP6",
                            "id2": "SNP7",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "SNP6",
                            "id2": "SNP8",
                            "color": "rgb(153,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 607.1735196149243,
                        "y": 592.8235196149242,
                        "z": 0,
                        "r": 441.97499999999985,
                        "a": 45
                    },
                    "level": 3,
                    "mass": 2,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "Gene7"
                    ],
                    "order": 3,
                    "parent": "Gene7",
                    "position": {
                        "x": 603.8280943978523,
                        "y": 589.4780943978523,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 3,
                "x": 603.8280943978523,
                "y": 589.4780943978523,
                "z": 0,
                "community": 7,
                "communityColor": "rgb(131,172,208)"
            },
            {
                "id": "SNP7",
                "color": "rgb(0,255,0)",
                "shape": "sphere",
                "layout": {
                    "angle": 18,
                    "children": [
                        "Gene6",
                        "SNP6"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "SNP6",
                            "id2": "SNP7",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "SNP7",
                            "id2": "Gene6",
                            "color": "rgb(51,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 855.107605052734,
                        "y": 462.40371478515647,
                        "z": 0,
                        "r": 589.3,
                        "a": 18
                    },
                    "level": 4,
                    "mass": 1.6666666666666665,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "SNP6",
                        "Gene6"
                    ],
                    "order": 4,
                    "parent": "SNP6",
                    "position": {
                        "x": 849.1081557717537,
                        "y": 460.45437554721565,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 2,
                "x": 849.1081557717537,
                "y": 460.45437554721565,
                "z": 0,
                "community": 4,
                "communityColor": "rgb(255,140,2)"
            },
            {
                "id": "SNP8",
                "color": "rgb(0,255,0)",
                "shape": "sphere",
                "layout": {
                    "angle": 72,
                    "children": [
                        "SNP6"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "SNP6",
                            "id2": "SNP8",
                            "color": "rgb(153,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 476.7537147851565,
                        "y": 840.7576050527339,
                        "z": 0,
                        "r": 589.3,
                        "a": 72
                    },
                    "level": 4,
                    "mass": 1.3333333333333333,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "SNP6"
                    ],
                    "order": 5,
                    "parent": "SNP6",
                    "position": {
                        "x": 474.80437554721567,
                        "y": 834.7581557717538,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 1,
                "x": 474.80437554721567,
                "y": 834.7581557717538,
                "z": 0,
                "community": 7,
                "communityColor": "rgb(131,172,208)"
            },
            {
                "id": "PH1",
                "color": "rgb(0,255,255)",
                "shape": "star",
                "layout": {
                    "angle": 162,
                    "children": [
                        "PH1a",
                        "PH1b",
                        "SNP1"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "SNP1",
                            "id2": "PH1",
                            "color": "rgb(51,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "PH1",
                            "id2": "PH1a",
                            "color": "rgb(102,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "PH1",
                            "id2": "PH1b",
                            "color": "rgb(102,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": -125.69320378955047,
                        "y": 416.8777860888674,
                        "z": 0,
                        "r": 441.97499999999997,
                        "a": 162
                    },
                    "level": 3,
                    "mass": 2,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "SNP1"
                    ],
                    "order": 6,
                    "parent": "SNP1",
                    "position": {
                        "x": -121.19361682881532,
                        "y": 415.41578166041177,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 3,
                "x": -121.19361682881532,
                "y": 415.41578166041177,
                "z": 0,
                "community": 8,
                "communityColor": "rgb(194,224,118)"
            },
            {
                "id": "PH1a",
                "color": "rgb(0,255,255)",
                "shape": "star",
                "parentNode": "PH1",
                "layout": {
                    "angle": 144,
                    "children": [
                        "PH1"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "PH1",
                            "id2": "PH1a",
                            "color": "rgb(102,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": -182.1037147851564,
                        "y": 626.6818491759543,
                        "z": 0,
                        "r": 589.2999999999998,
                        "a": 144
                    },
                    "level": 4,
                    "mass": 1.3333333333333333,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "PH1"
                    ],
                    "order": 7,
                    "parent": "PH1",
                    "position": {
                        "x": -177.00027840462343,
                        "y": 622.9739856065275,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 1,
                "x": -177.00027840462343,
                "y": 622.9739856065275,
                "z": 0,
                "community": 8,
                "communityColor": "rgb(194,224,118)"
            },
            {
                "id": "PH1b",
                "color": "rgb(0,255,255)",
                "shape": "star",
                "parentNode": "PH1",
                "layout": {
                    "angle": 180,
                    "children": [
                        "PH1"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "PH1",
                            "id2": "PH1b",
                            "color": "rgb(102,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": -294.6499999999999,
                        "y": 280.30000000000007,
                        "z": 0,
                        "r": 589.3,
                        "a": 180
                    },
                    "level": 4,
                    "mass": 1.3333333333333333,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "PH1"
                    ],
                    "order": 8,
                    "parent": "PH1",
                    "position": {
                        "x": -288.3418057148158,
                        "y": 280.30000000000007,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 1,
                "x": -288.3418057148158,
                "y": 280.30000000000007,
                "z": 0,
                "community": 8,
                "communityColor": "rgb(194,224,118)"
            },
            {
                "id": "PH2",
                "color": "rgb(0,255,255)",
                "shape": "star",
                "layout": {
                    "angle": 234,
                    "children": [
                        "PH2a",
                        "PH2b",
                        "SNP2"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "PH2",
                            "id2": "PH2a",
                            "color": "rgb(51,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "PH2",
                            "id2": "PH2b",
                            "color": "rgb(102,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "SNP2",
                            "id2": "PH2",
                            "color": "rgb(153,12,255)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 34.86361311803404,
                        "y": -77.26528608886724,
                        "z": 0,
                        "r": 441.97499999999997,
                        "a": 234
                    },
                    "level": 3,
                    "mass": 2,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [],
                    "order": 9,
                    "parent": "SNP2",
                    "position": {
                        "x": 37.64451079510434,
                        "y": -73.43770880346761,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 3,
                "x": 37.64451079510434,
                "y": -73.43770880346761,
                "z": 0,
                "community": 5,
                "communityColor": "rgb(105,150,150)"
            },
            {
                "id": "PH2a",
                "color": "rgb(0,255,255)",
                "shape": "star",
                "parentNode": "PH2",
                "layout": {
                    "angle": 216,
                    "children": [
                        "PH2"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "PH2",
                            "id2": "PH2a",
                            "color": "rgb(51,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": -182.1037147851565,
                        "y": -66.08184917595418,
                        "z": 0,
                        "r": 589.2999999999998,
                        "a": 216
                    },
                    "level": 4,
                    "mass": 1.3333333333333333,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "PH2"
                    ],
                    "order": 10,
                    "parent": "PH2",
                    "position": {
                        "x": -177.0002784046235,
                        "y": -62.3739856065273,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 1,
                "x": -177.0002784046235,
                "y": -62.3739856065273,
                "z": 0,
                "community": 5,
                "communityColor": "rgb(105,150,150)"
            },
            {
                "id": "PH2b",
                "color": "rgb(0,255,255)",
                "shape": "star",
                "parentNode": "PH2",
                "layout": {
                    "angle": 252,
                    "children": [
                        "PH2ba",
                        "PH2"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "PH2",
                            "id2": "PH2b",
                            "color": "rgb(102,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        },
                        {
                            "id1": "PH2b",
                            "id2": "PH2ba",
                            "color": "rgb(102,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 112.54628521484344,
                        "y": -280.15760505273397,
                        "z": 0,
                        "r": 589.3,
                        "a": 252
                    },
                    "level": 4,
                    "mass": 1.6666666666666665,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "PH2"
                    ],
                    "order": 11,
                    "parent": "PH2",
                    "position": {
                        "x": 114.49562445278423,
                        "y": -274.1581557717537,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 2,
                "x": 114.49562445278423,
                "y": -274.1581557717537,
                "z": 0,
                "community": 9,
                "communityColor": "rgb(250,220,90)"
            },
            {
                "id": "PH2ba",
                "color": "rgb(0,255,255)",
                "shape": "star",
                "parentNode": "PH2b",
                "layout": {
                    "angle": 252,
                    "children": [
                        "PH2b"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "PH2b",
                            "id2": "PH2ba",
                            "color": "rgb(102,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 67.0203565185543,
                        "y": -420.27200631591745,
                        "z": 0,
                        "r": 736.6249999999999,
                        "a": 252
                    },
                    "level": 5,
                    "mass": 1.3333333333333333,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "PH2b"
                    ],
                    "order": 12,
                    "parent": "PH2b",
                    "position": {
                        "x": 69.45703056598029,
                        "y": -412.772694714692,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 1,
                "x": 69.45703056598029,
                "y": -412.772694714692,
                "z": 0,
                "community": 9,
                "communityColor": "rgb(250,220,90)"
            },
            {
                "id": "PH3",
                "color": "rgb(0,255,255)",
                "shape": "star",
                "layout": {
                    "angle": 288,
                    "children": [
                        "SNP3"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "SNP3",
                            "id2": "PH3",
                            "color": "rgb(51,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 431.2277860888672,
                        "y": -140.04320378955038,
                        "z": 0,
                        "r": 441.97499999999985,
                        "a": 288
                    },
                    "level": 3,
                    "mass": 1.3333333333333333,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "SNP3"
                    ],
                    "order": 13,
                    "parent": "SNP3",
                    "position": {
                        "x": 429.7657816604116,
                        "y": -135.54361682881523,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 1,
                "x": 429.7657816604116,
                "y": -135.54361682881523,
                "z": 0,
                "community": 3,
                "communityColor": "rgb(248,204,3)"
            },
            {
                "id": "PH4",
                "color": "rgb(0,255,255)",
                "shape": "star",
                "layout": {
                    "angle": 0,
                    "children": [
                        "SNP4"
                    ],
                    "displacement": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "edges": [
                        {
                            "id1": "SNP4",
                            "id2": "PH4",
                            "color": "rgb(51,12,152)",
                            "type": "line",
                            "layout": {
                                "length": -1,
                                "weight": 1,
                                "coeff": -1
                            },
                            "weight": 1
                        }
                    ],
                    "force": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "hierarchy": "done",
                    "lastPosition": {
                        "x": 1325.9249999999997,
                        "y": 280.3,
                        "z": 0,
                        "r": 1031.2749999999996,
                        "a": 0
                    },
                    "level": 7,
                    "mass": 1.3333333333333333,
                    "metrics": {
                        "betweenness": -1,
                        "closeness": -1,
                        "degree": -1,
                        "eccentricity": -1
                    },
                    "neighbors": [
                        "SNP4"
                    ],
                    "order": 14,
                    "parent": "SNP4",
                    "position": {
                        "x": 1314.8856600009274,
                        "y": 280.3,
                        "z": 0
                    },
                    "prevPosition": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    },
                    "radius": 0,
                    "velocity": {
                        "x": 0,
                        "y": 0,
                        "z": 0
                    }
                },
                "nodeEdges": 1,
                "x": 1314.8856600009274,
                "y": 280.3,
                "z": 0,
                "community": 6,
                "communityColor": "rgb(183,120,68)"
            }
        ],
        "edges": [
            {
                "id1": "Gene1",
                "id2": "Gene2",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "SNP1",
                "id2": "PH1",
                "color": "rgb(51,12,152)",
                "type": "line"
            },
            {
                "id1": "Gene2",
                "id2": "Gene7",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "Gene2",
                "id2": "Gene8",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "Gene1",
                "id2": "Gene3",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "SNP4",
                "id2": "PH4",
                "color": "rgb(51,12,152)",
                "type": "line"
            },
            {
                "id1": "PH1",
                "id2": "PH1a",
                "color": "rgb(102,12,152)",
                "type": "line"
            },
            {
                "id1": "PH1",
                "id2": "PH1b",
                "color": "rgb(102,12,152)",
                "type": "line"
            },
            {
                "id1": "Gene4",
                "id2": "SNP3",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "Gene6",
                "id2": "SNP4",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "PH2",
                "id2": "PH2a",
                "color": "rgb(51,12,152)",
                "type": "line"
            },
            {
                "id1": "PH2",
                "id2": "PH2b",
                "color": "rgb(102,12,152)",
                "type": "line"
            },
            {
                "id1": "Gene6",
                "id2": "SNP5",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "Gene7",
                "id2": "SNP6",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "SNP6",
                "id2": "SNP7",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "Gene1",
                "id2": "Gene4",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "Gene1",
                "id2": "Gene5",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "SNP7",
                "id2": "Gene6",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "SNP6",
                "id2": "SNP8",
                "color": "rgb(153,12,255)",
                "type": "line"
            },
            {
                "id1": "Gene3",
                "id2": "SNP1",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "Gene3",
                "id2": "SNP2",
                "color": "rgb(51,12,255)",
                "type": "line"
            },
            {
                "id1": "SNP2",
                "id2": "PH2",
                "color": "rgb(153,12,255)",
                "type": "line"
            },
            {
                "id1": "SNP3",
                "id2": "PH3",
                "color": "rgb(51,12,152)",
                "type": "line"
            },
            {
                "id1": "PH2b",
                "id2": "PH2ba",
                "color": "rgb(102,12,152)",
                "type": "line"
            }
        ],
        "nodeIndices": {
            "Gene1": 0,
            "Gene2": 1,
            "Gene3": 2,
            "Gene4": 3,
            "Gene5": 4,
            "Gene6": 5,
            "Gene7": 6,
            "Gene8": 7,
            "SNP1": 8,
            "SNP2": 9,
            "SNP3": 10,
            "SNP4": 11,
            "SNP5": 12,
            "SNP6": 13,
            "SNP7": 14,
            "SNP8": 15,
            "PH1": 16,
            "PH1a": 17,
            "PH1b": 18,
            "PH2": 19,
            "PH2a": 20,
            "PH2b": 21,
            "PH2ba": 22,
            "PH3": 23,
            "PH4": 24
        }
    },
    config={
        "graphType": "Network",
        "networkLayoutType": "radial",
        "nodeFontColor": "rgb(29,34,43)",
        "nodeScaleFontFactor": 2,
        "showAnimation": True,
        "title": "Radial Network",
        "calculateLayout": False
    },
    width=500,
    height=500,
    events=CXEvents(),
    after_render=[
        [
            "setDimensions",
            [
                613,
                613,
                True
            ]
        ]
    ],
    other_init_params={
        "version": 35,
        "events": False,
        "info": False,
        "afterRenderInit": False,
        "noValidate": True
    }
)

display = CXNoteBook(cx) 
display.render(output_file="network_4.html")
