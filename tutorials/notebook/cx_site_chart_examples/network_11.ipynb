# %% [markdown]
# # Example: CanvasXpress network Chart No. 11
#
# This example page demonstrates how to, using the Python package, create a chart that matches the CanvasXpress online example located at:
#
# https://www.canvasxpress.org/examples/network-11.html
#
# This example is generated using the reproducible JSON obtained from the above page and the `canvasxpress.util.generator.generate_canvasxpress_code_from_json_file()` function.
#
# Everything required for the chart to render is included in the code below.  Simply run the code block.

# %%
from canvasxpress.canvas import CanvasXpress 
from canvasxpress.js.collection import CXEvents 
from canvasxpress.render.jupyter import CXNoteBook 

cx = CanvasXpress(
    render_to="network111",
    data={
        "nodes": [
            {
                "id": "fff69",
                "x": 347.6,
                "y": 1194.5,
                "width": 174,
                "height": 64,
                "group": [
                    "dacce",
                    "c0b1d",
                    "f3cd6"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "-29"
            },
            {
                "graphid": "f3cd6",
                "groupref": "fff69",
                "width": 169,
                "height": 59,
                "zorder": "-29",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(102,102,102)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 347.6,
                "y": 1194.5,
                "id": "f3cd6",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(102,102,102)",
                "outline": "rgb(102,102,102)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "fff69"
            },
            {
                "id": "ce48b",
                "x": 1237.8,
                "y": 1308.4,
                "width": 98,
                "height": 59,
                "group": [
                    "f3a24",
                    "e8c6b",
                    "b16c1"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "-27"
            },
            {
                "graphid": "b16c1",
                "groupref": "ce48b",
                "width": 93,
                "height": 54,
                "zorder": "-27",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(204,204,204)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 1237.8,
                "y": 1308.4,
                "id": "b16c1",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(204,204,204)",
                "outline": "rgb(204,204,204)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "ce48b"
            },
            {
                "graphid": "e8c6b",
                "groupref": "ce48b",
                "width": 80,
                "height": 20,
                "zorder": "-25",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1235.2,
                "y": 1297.9,
                "label": "GTPaseactivator",
                "id": "e8c6b",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "ce48b"
            },
            {
                "graphid": "f3a24",
                "type": "GeneProduct",
                "groupref": "ce48b",
                "width": 80,
                "height": 20,
                "zorder": "-23",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000179387",
                "id": "f3a24",
                "nodeName": "datanode",
                "x": 1238.5,
                "y": 1321.7,
                "label": "ELMOD2",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "ce48b"
            },
            {
                "id": "e2ca2",
                "x": 694.1,
                "y": 819.5,
                "width": 109,
                "height": 266,
                "group": [
                    "b6a45",
                    "d3a67",
                    "f813c",
                    "baeff",
                    "d5b1a",
                    "deef9",
                    "d91aa",
                    "fada0",
                    "dfac1",
                    "b835e",
                    "d37a4",
                    "aef45"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "-21"
            },
            {
                "graphid": "aef45",
                "groupref": "e2ca2",
                "width": 104,
                "height": 261,
                "zorder": "-21",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 694.1,
                "y": 819.5,
                "id": "aef45",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "e2ca2"
            },
            {
                "id": "bc57d",
                "x": 740.2,
                "y": 1160.95,
                "width": 101,
                "height": 205.9000000000001,
                "group": [
                    "db6dc",
                    "b3f1d",
                    "a52cb",
                    "f7a22",
                    "d31d4",
                    "efb4d",
                    "b9253",
                    "b6351",
                    "c0f16"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "-19"
            },
            {
                "graphid": "c0f16",
                "groupref": "bc57d",
                "width": 96,
                "height": 195,
                "zorder": "-19",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 740.2,
                "y": 1163.9,
                "id": "c0f16",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "bc57d"
            },
            {
                "id": "e1c3b",
                "x": 1290.1,
                "y": 852.9,
                "width": 97,
                "height": 88,
                "group": [
                    "fb0bc",
                    "d0c59",
                    "d16dc",
                    "ed541"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "-17"
            },
            {
                "graphid": "ed541",
                "groupref": "e1c3b",
                "width": 92,
                "height": 83,
                "zorder": "-17",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(204,204,204)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 1290.1,
                "y": 852.9,
                "id": "ed541",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(204,204,204)",
                "outline": "rgb(204,204,204)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "e1c3b"
            },
            {
                "graphid": "a83c9",
                "width": 94,
                "height": 101,
                "zorder": "-15",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(204,204,204)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 542.5,
                "y": 1197.7,
                "id": "a83c9",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(204,204,204)",
                "outline": "rgb(204,204,204)",
                "hideLabel": True,
                "hideTooltip": False
            },
            {
                "id": "e0f0a",
                "x": 939.7,
                "y": 778.6,
                "width": 130,
                "height": 109,
                "group": [
                    "c6f3d",
                    "f2f91",
                    "d7cbe",
                    "fd6d4",
                    "d318a"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "-13"
            },
            {
                "graphid": "d318a",
                "groupref": "e0f0a",
                "width": 125,
                "height": 104,
                "zorder": "-13",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(204,204,204)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 939.7,
                "y": 778.6,
                "id": "d318a",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(204,204,204)",
                "outline": "rgb(204,204,204)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "e0f0a"
            },
            {
                "id": "d8be9",
                "x": 564.45,
                "y": 968,
                "width": 124.89999999999998,
                "height": 109,
                "group": [
                    "b717b",
                    "e6d9c",
                    "ee899",
                    "c5c8c",
                    "bea67"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "-11"
            },
            {
                "graphid": "bea67",
                "groupref": "d8be9",
                "width": 107,
                "height": 104,
                "zorder": "-11",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 570.9,
                "y": 968,
                "id": "bea67",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "d8be9"
            },
            {
                "id": "f358b",
                "x": 1286.7,
                "y": 1114.85,
                "width": 111,
                "height": 125.29999999999995,
                "group": [
                    "c358b",
                    "d01e0",
                    "bee91",
                    "ae474",
                    "ed142",
                    "adca6"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "-9"
            },
            {
                "graphid": "adca6",
                "groupref": "f358b",
                "width": 102,
                "height": 119,
                "zorder": "-9",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(102,102,102)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 1287.1,
                "y": 1115.5,
                "id": "adca6",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(102,102,102)",
                "outline": "rgb(102,102,102)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "f358b"
            },
            {
                "id": "daaa7",
                "x": 1004.2,
                "y": 1030.9,
                "width": 371,
                "height": 240,
                "group": [
                    "ff8cd",
                    "db804",
                    "d8e39",
                    "bc89e",
                    "e39b2",
                    "bfcf5",
                    "d0320",
                    "f95b1",
                    "c74c5",
                    "c8e45",
                    "e40a8",
                    "f8ed1",
                    "e508c",
                    "bf0e6",
                    "b666e",
                    "b1aab",
                    "df74c"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "-7"
            },
            {
                "graphid": "bf0e6",
                "groupref": "daaa7",
                "width": 366,
                "height": 235,
                "zorder": "-7",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 1004.2,
                "y": 1030.9,
                "id": "bf0e6",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "daaa7"
            },
            {
                "id": "db3f5",
                "x": 499.9,
                "y": 697.8,
                "width": 126,
                "height": 134,
                "group": [
                    "c8f9f",
                    "d8fb3",
                    "f0f62",
                    "eb6f5",
                    "ee82d",
                    "f8281"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "-4"
            },
            {
                "graphid": "f8281",
                "groupref": "db3f5",
                "width": 111,
                "height": 129,
                "zorder": "-4",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 498.8,
                "y": 697.8,
                "id": "f8281",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "db3f5"
            },
            {
                "id": "e7c4b",
                "x": 135.7,
                "y": 734.3,
                "width": 233,
                "height": 158,
                "group": [
                    "dcf46",
                    "b8cf6"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "-2"
            },
            {
                "graphid": "b8cf6",
                "groupref": "e7c4b",
                "width": 228,
                "height": 153,
                "zorder": "-2",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 135.7,
                "y": 734.3,
                "id": "b8cf6",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "e7c4b"
            },
            {
                "graphid": "a260c",
                "width": 76,
                "height": 49,
                "zorder": "16384",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 382.6,
                "y": 443,
                "id": "a260c",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False
            },
            {
                "graphid": "ec186",
                "width": 71,
                "height": 55,
                "zorder": "16386",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(102,102,102)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 275.2,
                "y": 449.3,
                "id": "ec186",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(102,102,102)",
                "outline": "rgb(102,102,102)",
                "hideLabel": True,
                "hideTooltip": False
            },
            {
                "graphid": "b68bb",
                "width": 100,
                "height": 51,
                "zorder": "16388",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 782.4,
                "y": 612.3,
                "id": "b68bb",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False
            },
            {
                "graphid": "a268b",
                "width": 76,
                "height": 53,
                "zorder": "16390",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 797.9,
                "y": 436.2,
                "id": "a268b",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False
            },
            {
                "graphid": "ebdf3",
                "width": 77,
                "height": 44,
                "zorder": "16392",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 689,
                "y": 439.5,
                "id": "ebdf3",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False
            },
            {
                "id": "c63cd",
                "x": 347.6,
                "y": 1447.7,
                "width": 153,
                "height": 62,
                "group": [
                    "ae333",
                    "b5376",
                    "e197c"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "16394"
            },
            {
                "graphid": "e197c",
                "groupref": "c63cd",
                "width": 148,
                "height": 57,
                "zorder": "16394",
                "fontsize": "10",
                "valign": "Middle",
                "linethickness": "5.0",
                "color": "rgba(255,255,255,0)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 347.6,
                "y": 1447.7,
                "id": "e197c",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(51,51,51)",
                "outline": "rgb(51,51,51)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "c63cd"
            },
            {
                "graphid": "a6a27",
                "width": 101,
                "height": 46,
                "zorder": "16396",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 155.9,
                "y": 437.2,
                "id": "a6a27",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False
            },
            {
                "graphid": "b4e72",
                "width": 149,
                "height": 33,
                "zorder": "16398",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 684.9,
                "y": 534.4,
                "id": "b4e72",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False
            },
            {
                "graphid": "f6699",
                "width": 53,
                "height": 56,
                "zorder": "16400",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(102,102,102)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 512.3,
                "y": 458.7,
                "id": "f6699",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(102,102,102)",
                "outline": "rgb(102,102,102)",
                "hideLabel": True,
                "hideTooltip": False
            },
            {
                "graphid": "f806d",
                "width": 108,
                "height": 53,
                "zorder": "16402",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 386.6,
                "y": 584.2,
                "id": "f806d",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False
            },
            {
                "graphid": "e136b",
                "width": 402,
                "height": 310,
                "zorder": "16404",
                "fontsize": "10",
                "valign": "Middle",
                "rotation": "0.0047433706724440495",
                "nodeName": "shape",
                "x": 1376.8,
                "y": 289.4,
                "id": "e136b",
                "labelSize": 10,
                "rotate": 180.27177512019716,
                "shape": "roundrect",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "hideLabel": True,
                "hideTooltip": False
            },
            {
                "id": "cb3c3",
                "x": 347.6,
                "y": 1325,
                "width": 237,
                "height": 60,
                "group": [
                    "e3a94",
                    "e5051",
                    "fa302"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "16406"
            },
            {
                "graphid": "fa302",
                "groupref": "cb3c3",
                "width": 223,
                "height": 55,
                "zorder": "16406",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 347.6,
                "y": 1325,
                "id": "fa302",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "cb3c3"
            },
            {
                "graphid": "a9abb",
                "width": 380,
                "height": 20,
                "zorder": "28672",
                "fontsize": "10",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1372.2,
                "y": 228.9,
                "label": "KE1 - Induction of inflammatory cytokines and acute phase response",
                "id": "a9abb",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "bef61",
                "width": 380,
                "height": 20,
                "zorder": "28672",
                "fontsize": "10",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1372.2,
                "y": 287.9,
                "label": "KE5 - Excessive ECM deposition",
                "id": "bef61",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "d558e",
                "width": 380,
                "height": 26,
                "zorder": "28672",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1372.2,
                "y": 311,
                "label": "AE - Associative Event",
                "id": "d558e",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "dd82c",
                "width": 380,
                "height": 20,
                "zorder": "28672",
                "fontsize": "10",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1372.2,
                "y": 258,
                "label": "KE3 - TH2/M2 response, secretion/activation of interleukins and growth factors",
                "id": "dd82c",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "e56b9",
                "width": 380,
                "height": 20,
                "zorder": "28672",
                "fontsize": "10",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1373.2,
                "y": 427.1,
                "label": "MIE - Cellular sensing of substance",
                "id": "e56b9",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "e94a1",
                "width": 380,
                "height": 20,
                "zorder": "28672",
                "fontsize": "10",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1371.1,
                "y": 326.9,
                "label": "AE1 - Increase of reactive oxygen species levels",
                "id": "e94a1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "eb476",
                "width": 380,
                "height": 20,
                "zorder": "28672",
                "fontsize": "10",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1371.1,
                "y": 340.3,
                "label": "AE2 - Cellular toxicity, cell death",
                "id": "eb476",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "efbce",
                "width": 380,
                "height": 20,
                "zorder": "28672",
                "fontsize": "10",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1372.2,
                "y": 242.9,
                "label": "KE2 - a. Retention/repeated exposure, b. persistent inflammation",
                "id": "efbce",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "f0ff8",
                "width": 180,
                "height": 20,
                "zorder": "28672",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1272,
                "y": 413,
                "label": "MIE - Molecular Initiating Event",
                "id": "f0ff8",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "fb826",
                "width": 380,
                "height": 20,
                "zorder": "28672",
                "fontsize": "10",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1372.2,
                "y": 390.1,
                "label": "AO - Fibrosis",
                "id": "fb826",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "fe1d5",
                "width": 380,
                "height": 20,
                "zorder": "28672",
                "fontsize": "10",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1372.2,
                "y": 273.6,
                "label": "KE4 - Fibroblast & myofibroblast proliferation",
                "id": "fe1d5",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "dae5b",
                "width": 380,
                "height": 26,
                "zorder": "28674",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1372.2,
                "y": 211.9,
                "label": "KE - Key Event",
                "id": "dae5b",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "ef6c1",
                "width": 380,
                "height": 24,
                "zorder": "28676",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1372.2,
                "y": 372.3,
                "label": "AO - Adverse Outcome",
                "id": "ef6c1",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "be2d9",
                "type": "Pathway",
                "width": 142,
                "height": 25,
                "zorder": "32768",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP3929",
                "id": "be2d9",
                "nodeName": "datanode",
                "x": 1036,
                "y": 957,
                "label": "Chemokine signaling",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)"
            },
            {
                "graphid": "c8f9f",
                "type": "Pathway",
                "groupref": "db3f5",
                "width": 121,
                "height": 34,
                "zorder": "32768",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP129",
                "id": "c8f9f",
                "nodeName": "datanode",
                "x": 499.9,
                "y": 652.4,
                "label": "Matrixmetalloproteinases",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "db3f5"
            },
            {
                "graphid": "dacce",
                "type": "Pathway",
                "groupref": "fff69",
                "width": 131,
                "height": 34,
                "zorder": "32768",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP2798",
                "id": "dacce",
                "nodeName": "datanode",
                "x": 347.6,
                "y": 1184,
                "label": "Collagen producton",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "fff69"
            },
            {
                "graphid": "db2ca",
                "type": "Pathway",
                "width": 89,
                "height": 29,
                "zorder": "32768",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP474",
                "id": "db2ca",
                "nodeName": "datanode",
                "x": 96.3,
                "y": 681.5,
                "label": "Chondrocytedifferentiation",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)"
            },
            {
                "graphid": "f0ad6",
                "type": "Pathway",
                "width": 83,
                "height": 23,
                "zorder": "32768",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP2666",
                "id": "f0ad6",
                "nodeName": "datanode",
                "x": 176.3,
                "y": 765.5,
                "label": "Stressfibre assembly",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)"
            },
            {
                "graphid": "db6dc",
                "type": "Pathway",
                "groupref": "bc57d",
                "width": 82,
                "height": 48,
                "zorder": "32770",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP2848",
                "id": "db6dc",
                "nodeName": "datanode",
                "x": 742.8,
                "y": 1084.5,
                "label": "DifferentiationPathway",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "bc57d"
            },
            {
                "graphid": "c358b",
                "type": "Pathway",
                "groupref": "f358b",
                "width": 106,
                "height": 36,
                "zorder": "32776",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP2884",
                "id": "c358b",
                "nodeName": "datanode",
                "x": 1286.7,
                "y": 1072.7,
                "label": "NRF2signaling",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "f358b"
            },
            {
                "graphid": "b717b",
                "type": "Pathway",
                "groupref": "d8be9",
                "width": 63,
                "height": 31,
                "zorder": "32782",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP560",
                "id": "b717b",
                "nodeName": "datanode",
                "x": 570.5,
                "y": 932.1,
                "label": "TGF betasignaling",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "d8be9"
            },
            {
                "graphid": "b6a45",
                "type": "Pathway",
                "groupref": "e2ca2",
                "width": 100,
                "height": 37,
                "zorder": "32792",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP530",
                "id": "b6a45",
                "nodeName": "datanode",
                "x": 695,
                "y": 710.1,
                "label": "Cytokinesand inflammatoryresponse",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "e2ca2"
            },
            {
                "graphid": "b666e",
                "groupref": "daaa7",
                "width": 77,
                "height": 39,
                "zorder": "32798",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(102,102,102)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 1013.3,
                "y": 1113.1,
                "id": "b666e",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(102,102,102)",
                "outline": "rgb(102,102,102)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "daaa7"
            },
            {
                "graphid": "ff8cd",
                "type": "Pathway",
                "groupref": "daaa7",
                "width": 69,
                "height": 22,
                "zorder": "32800",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP254",
                "id": "ff8cd",
                "nodeName": "datanode",
                "x": 1013,
                "y": 1103.5,
                "label": "Apoptosis",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "daaa7"
            },
            {
                "id": "c700d",
                "x": 1010,
                "y": 135.5,
                "width": 104,
                "height": 61,
                "group": [
                    "d8794",
                    "c9df5",
                    "f437b"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "32939"
            },
            {
                "graphid": "f437b",
                "groupref": "c700d",
                "width": 99,
                "height": 56,
                "zorder": "32939",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(204,204,204)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 1010,
                "y": 135.5,
                "id": "f437b",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(204,204,204)",
                "outline": "rgb(204,204,204)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "c700d"
            },
            {
                "id": "dfe74",
                "x": 907.8,
                "y": 162.8,
                "width": 98,
                "height": 106,
                "group": [
                    "d1e20",
                    "fde8e",
                    "c2f1d",
                    "a19cc",
                    "c51a3"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "32943"
            },
            {
                "graphid": "c51a3",
                "groupref": "dfe74",
                "width": 93,
                "height": 101,
                "zorder": "32943",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(204,204,204)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 907.8,
                "y": 162.8,
                "id": "c51a3",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(204,204,204)",
                "outline": "rgb(204,204,204)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "dfe74"
            },
            {
                "id": "d69c6",
                "x": 178.6,
                "y": 776.6,
                "width": 103,
                "height": 60,
                "group": [
                    "f52e2",
                    "de9f1"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "32947"
            },
            {
                "graphid": "de9f1",
                "groupref": "d69c6",
                "width": 98,
                "height": 55,
                "zorder": "32947",
                "fontsize": "10",
                "valign": "Middle",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 178.6,
                "y": 776.6,
                "id": "de9f1",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "d69c6"
            },
            {
                "graphid": "b1aab",
                "groupref": "daaa7",
                "width": 103,
                "height": 76,
                "zorder": "32949",
                "fontsize": "10",
                "valign": "Middle",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 1125,
                "y": 1084.7,
                "id": "b1aab",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "daaa7"
            },
            {
                "id": "b8425",
                "x": 1375.2,
                "y": 1241.1,
                "width": 102,
                "height": 59,
                "group": [
                    "edbb6",
                    "ab70b",
                    "ebfaf"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "32951"
            },
            {
                "graphid": "ebfaf",
                "groupref": "b8425",
                "width": 97,
                "height": 54,
                "zorder": "32951",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(204,204,204)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 1375.2,
                "y": 1241.1,
                "id": "ebfaf",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(204,204,204)",
                "outline": "rgb(204,204,204)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "b8425"
            },
            {
                "graphid": "df74c",
                "groupref": "daaa7",
                "width": 102,
                "height": 154,
                "zorder": "32953",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(229,229,229)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 884.3,
                "y": 999.2,
                "id": "df74c",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(229,229,229)",
                "outline": "rgb(229,229,229)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "daaa7"
            },
            {
                "id": "d9cec",
                "x": 540.2,
                "y": 1351.7,
                "width": 130,
                "height": 167,
                "group": [
                    "f8634",
                    "c98db",
                    "df04d",
                    "cdc29",
                    "a37d8",
                    "e5ae2",
                    "d3f8d"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "32957"
            },
            {
                "graphid": "d3f8d",
                "groupref": "d9cec",
                "width": 125,
                "height": 162,
                "zorder": "32957",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(102,102,102)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 540.2,
                "y": 1351.7,
                "id": "d3f8d",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(102,102,102)",
                "outline": "rgb(102,102,102)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "d9cec"
            },
            {
                "id": "b2b69",
                "x": 1134.6,
                "y": 806,
                "width": 124,
                "height": 105,
                "group": [
                    "dbdee",
                    "ca8a4",
                    "ec97b",
                    "bf6c8",
                    "ce679"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "32959"
            },
            {
                "graphid": "ce679",
                "groupref": "b2b69",
                "width": 119,
                "height": 100,
                "zorder": "32959",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(153,153,153)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 1134.6,
                "y": 806,
                "id": "ce679",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(153,153,153)",
                "outline": "rgb(153,153,153)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "b2b69"
            },
            {
                "id": "bda4a",
                "x": 1010.0999999999999,
                "y": 196.7,
                "width": 98.99999999999989,
                "height": 61,
                "group": [
                    "b96f2",
                    "cbcb5",
                    "ffc83"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "32965"
            },
            {
                "graphid": "ffc83",
                "groupref": "bda4a",
                "width": 94,
                "height": 56,
                "zorder": "32965",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgb(204,204,204)",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 1010.1,
                "y": 196.7,
                "id": "ffc83",
                "labelSize": 10,
                "rotate": 180,
                "shape": "roundrect",
                "labelColor": "rgb(204,204,204)",
                "outline": "rgb(204,204,204)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "bda4a"
            },
            {
                "id": "ee465",
                "x": 497,
                "y": 211.3,
                "width": 396,
                "height": 31,
                "group": [
                    "c5ee0"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "32971"
            },
            {
                "graphid": "c5ee0",
                "groupref": "ee465",
                "width": 396,
                "height": 31,
                "zorder": "32971",
                "fontsize": "10",
                "valign": "Middle",
                "rotation": "0.0",
                "nodeName": "shape",
                "x": 497,
                "y": 211.3,
                "id": "c5ee0",
                "labelSize": 10,
                "rotate": 180,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "hideLabel": True,
                "hideTooltip": False,
                "parentNode": "ee465"
            },
            {
                "graphid": "d16dc",
                "groupref": "e1c3b",
                "width": 80,
                "height": 22,
                "zorder": "32973",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1289.1,
                "y": 829.6,
                "label": "GPCRsignaling",
                "id": "d16dc",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "e1c3b"
            },
            {
                "graphid": "a37d8",
                "groupref": "d9cec",
                "width": 106,
                "height": 32,
                "zorder": "32975",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 541.8,
                "y": 1297.1,
                "label": "Regulation ofreactive oxygen speciesmetabolism",
                "id": "a37d8",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "d9cec"
            },
            {
                "graphid": "ae333",
                "groupref": "c63cd",
                "width": 117,
                "height": 20,
                "zorder": "32981",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 347.6,
                "y": 1458.1,
                "label": "Pulmonary fibrosis",
                "id": "ae333",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "c63cd"
            },
            {
                "graphid": "f309d",
                "width": 133,
                "height": 90,
                "zorder": "32983",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 354,
                "y": 338.8,
                "label": "Fibroblastproliferation, resistance to apoptosis, differentiationinto myofibroblasts, collagen production",
                "id": "f309d",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "fd6d4",
                "groupref": "e0f0a",
                "width": 100,
                "height": 20,
                "zorder": "32987",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 938.1,
                "y": 743.3,
                "label": "Pulmonary surfactantproteins",
                "id": "fd6d4",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "e0f0a"
            },
            {
                "graphid": "e3a94",
                "groupref": "cb3c3",
                "width": 232,
                "height": 24,
                "zorder": "32989",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 347.6,
                "y": 1318.2,
                "label": "Excess deposition and/or reduced turnover of extracellular matrix (ECM)",
                "id": "e3a94",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "cb3c3"
            },
            {
                "graphid": "d4612",
                "width": 133,
                "height": 90,
                "zorder": "32991",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 498.5,
                "y": 338.8,
                "label": "Macrophage-relatedoxidative stressandinflammasome activation",
                "id": "d4612",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "e40a8",
                "groupref": "daaa7",
                "width": 50,
                "height": 12,
                "zorder": "32993",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 883.6,
                "y": 1061,
                "label": "MIE",
                "id": "e40a8",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "cbcb5",
                "groupref": "bda4a",
                "width": 90,
                "height": 23,
                "zorder": "32995",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1011.8,
                "y": 183.9,
                "label": "Salivarysecretion",
                "id": "cbcb5",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "bda4a"
            },
            {
                "graphid": "fb58a",
                "width": 128,
                "height": 90,
                "zorder": "32997",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 645.2,
                "y": 338.8,
                "label": "Epithelial injury andapoptosis:disturbed interactionwith mesenchymal cells,epithelial-mesenchymaltransition",
                "id": "fb58a",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "a19cc",
                "groupref": "dfe74",
                "width": 80,
                "height": 20,
                "zorder": "32999",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 908.5,
                "y": 126.8,
                "label": "Telomereorganization",
                "id": "a19cc",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "dfe74"
            },
            {
                "graphid": "ab70b",
                "groupref": "b8425",
                "width": 92,
                "height": 20,
                "zorder": "33001",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1372.9,
                "y": 1230,
                "label": "Serine-typepeptidase activity",
                "id": "ab70b",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "b8425"
            },
            {
                "graphid": "ec97b",
                "groupref": "b2b69",
                "width": 109,
                "height": 20,
                "zorder": "33003",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1132.8,
                "y": 774.7,
                "label": "Leukocyte/Myeloid celldifferentiation",
                "id": "ec97b",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "b2b69"
            },
            {
                "graphid": "cf98e",
                "width": 83,
                "height": 36,
                "zorder": "33005",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 541.1,
                "y": 1179.1,
                "label": "Intermediatefilamentcytoskeleton",
                "id": "cf98e",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "c9df5",
                "groupref": "c700d",
                "width": 97,
                "height": 19,
                "zorder": "33007",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1011,
                "y": 122.3,
                "label": "Methylation/chromatin binding",
                "id": "c9df5",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "c700d"
            },
            {
                "graphid": "d01e4",
                "width": 182,
                "height": 61,
                "zorder": "33011",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 498.2,
                "y": 136.3,
                "label": "Lung injury (known or unknown) combined with tissue response (normal or abnormal)",
                "id": "d01e4",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "d1e20",
                "type": "GeneProduct",
                "groupref": "dfe74",
                "width": 80,
                "height": 20,
                "zorder": "33013",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000258366",
                "id": "d1e20",
                "nodeName": "datanode",
                "x": 907.8,
                "y": 177.3,
                "label": "RTEL1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "dfe74"
            },
            {
                "graphid": "d3a67",
                "type": "GeneProduct",
                "groupref": "e2ca2",
                "width": 80,
                "height": 20,
                "zorder": "33015",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000081041",
                "id": "d3a67",
                "nodeName": "datanode",
                "x": 693.3,
                "y": 761.9,
                "label": "CXCL2",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e2ca2"
            },
            {
                "graphid": "e6d9c",
                "type": "GeneProduct",
                "groupref": "d8be9",
                "width": 80,
                "height": 20,
                "zorder": "33017",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000118785",
                "id": "e6d9c",
                "nodeName": "datanode",
                "x": 571.3,
                "y": 982.3,
                "label": "SPP1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "d8be9"
            },
            {
                "graphid": "edbb6",
                "type": "GeneProduct",
                "groupref": "b8425",
                "width": 80,
                "height": 20,
                "zorder": "33019",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000142002",
                "id": "edbb6",
                "nodeName": "datanode",
                "x": 1374.6,
                "y": 1255.2,
                "label": "DPP9",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "b8425"
            },
            {
                "graphid": "b3f1d",
                "type": "GeneProduct",
                "groupref": "bc57d",
                "width": 80,
                "height": 20,
                "zorder": "33021",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000113578",
                "id": "b3f1d",
                "nodeName": "datanode",
                "x": 740.6,
                "y": 1169.6,
                "label": "FGF1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "bc57d"
            },
            {
                "graphid": "db804",
                "type": "GeneProduct",
                "groupref": "daaa7",
                "width": 79,
                "height": 21,
                "zorder": "33023",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000275302",
                "id": "db804",
                "nodeName": "datanode",
                "x": 881.6,
                "y": 1009.3,
                "label": "CCL4",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "aff39",
                "type": "GeneProduct",
                "width": 80,
                "height": 20,
                "zorder": "33025",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000101665",
                "id": "aff39",
                "nodeName": "datanode",
                "x": 348.1,
                "y": 707.3,
                "label": "SMAD7",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)"
            },
            {
                "graphid": "fde8e",
                "type": "GeneProduct",
                "groupref": "dfe74",
                "width": 80,
                "height": 20,
                "zorder": "33027",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000270141",
                "id": "fde8e",
                "nodeName": "datanode",
                "x": 907.8,
                "y": 197.6,
                "label": "TERC",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "dfe74"
            },
            {
                "id": "f76b2",
                "x": 199.1,
                "y": 696.95,
                "width": 85,
                "height": 44.5,
                "group": [
                    "a132b",
                    "fb9d6"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33029"
            },
            {
                "graphid": "a132b",
                "type": "GeneProduct",
                "groupref": "f76b2",
                "width": 80,
                "height": 20,
                "zorder": "33029",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000118523",
                "id": "a132b",
                "nodeName": "datanode",
                "x": 199.1,
                "y": 687.2,
                "label": "CTGF",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "f76b2"
            },
            {
                "graphid": "c6f3d",
                "type": "GeneProduct",
                "groupref": "e0f0a",
                "width": 80,
                "height": 20,
                "zorder": "33031",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000185303",
                "id": "c6f3d",
                "nodeName": "datanode",
                "x": 936.1,
                "y": 788.2,
                "label": "SFTPA2",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e0f0a"
            },
            {
                "graphid": "ecb8e",
                "type": "GeneProduct",
                "width": 80,
                "height": 20,
                "zorder": "33033",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000140694",
                "id": "ecb8e",
                "nodeName": "datanode",
                "x": 893,
                "y": 680,
                "label": "PARN",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)"
            },
            {
                "id": "a3a34",
                "x": 804.7,
                "y": 440.6,
                "width": 98,
                "height": 52.80000000000001,
                "group": [
                    "cc748",
                    "d9434"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33035"
            },
            {
                "graphid": "cc748",
                "type": "Pathway",
                "groupref": "a3a34",
                "width": 58,
                "height": 36,
                "zorder": "33035",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP382",
                "id": "cc748",
                "nodeName": "datanode",
                "x": 787.2,
                "y": 446.5,
                "label": "MAPKsignaling",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "a3a34"
            },
            {
                "graphid": "d8e39",
                "type": "GeneProduct",
                "groupref": "daaa7",
                "width": 80,
                "height": 20,
                "zorder": "33037",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000108691",
                "id": "d8e39",
                "nodeName": "datanode",
                "x": 1013.7,
                "y": 1027.7,
                "label": "CCL2",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "d01e0",
                "type": "GeneProduct",
                "groupref": "f358b",
                "width": 80,
                "height": 20,
                "zorder": "33039",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000197249",
                "id": "d01e0",
                "nodeName": "datanode",
                "x": 1288.6,
                "y": 1139.4,
                "label": "SERPINA1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "f358b"
            },
            {
                "graphid": "ee899",
                "type": "GeneProduct",
                "groupref": "d8be9",
                "width": 79,
                "height": 20,
                "zorder": "33041",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000136603",
                "id": "ee899",
                "nodeName": "datanode",
                "x": 571.3,
                "y": 962.3,
                "label": "SKIL",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "d8be9"
            },
            {
                "graphid": "d8bf5",
                "type": "GeneProduct",
                "width": 80,
                "height": 20,
                "zorder": "33043",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000232810",
                "id": "d8bf5",
                "nodeName": "datanode",
                "x": 384,
                "y": 536.3,
                "label": "TNF",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)"
            },
            {
                "graphid": "f2f91",
                "type": "GeneProduct",
                "groupref": "e0f0a",
                "width": 80,
                "height": 20,
                "zorder": "33045",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000122852",
                "id": "f2f91",
                "nodeName": "datanode",
                "x": 936.1,
                "y": 768.2,
                "label": "SFTPA1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e0f0a"
            },
            {
                "graphid": "f813c",
                "type": "GeneProduct",
                "groupref": "e2ca2",
                "width": 79,
                "height": 20,
                "zorder": "33047",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000136244",
                "id": "f813c",
                "nodeName": "datanode",
                "x": 693.3,
                "y": 901.9,
                "label": "IL6",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e2ca2"
            },
            {
                "id": "a5cb6",
                "x": 502.75,
                "y": 212.2,
                "width": 373.90000000000003,
                "height": 27,
                "group": [
                    "f8565",
                    "bae9c",
                    "b9166"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33049"
            },
            {
                "graphid": "f8565",
                "type": "Pathway",
                "groupref": "a5cb6",
                "width": 121,
                "height": 17,
                "zorder": "33049",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP408",
                "id": "f8565",
                "nodeName": "datanode",
                "x": 477.3,
                "y": 211.8,
                "label": "Oxidative Stress",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "a5cb6"
            },
            {
                "graphid": "f8634",
                "type": "GeneProduct",
                "groupref": "d9cec",
                "width": 80,
                "height": 20,
                "zorder": "33051",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000078401",
                "id": "f8634",
                "nodeName": "datanode",
                "x": 540.2,
                "y": 1351.8,
                "label": "EDN1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "d9cec"
            },
            {
                "graphid": "f52e2",
                "type": "GeneProduct",
                "groupref": "d69c6",
                "width": 80,
                "height": 20,
                "zorder": "33053",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000049540",
                "id": "f52e2",
                "nodeName": "datanode",
                "x": 178.9,
                "y": 790.5,
                "label": "ELN",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "d69c6"
            },
            {
                "graphid": "baeff",
                "type": "GeneProduct",
                "groupref": "e2ca2",
                "width": 79,
                "height": 20,
                "zorder": "33055",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000108342",
                "id": "baeff",
                "nodeName": "datanode",
                "x": 693.3,
                "y": 781.9,
                "label": "CSF3",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e2ca2"
            },
            {
                "id": "eb9d3",
                "x": 70.2,
                "y": 782.55,
                "width": 85,
                "height": 44.5,
                "group": [
                    "b0bbb",
                    "f7c0c"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33057"
            },
            {
                "graphid": "b0bbb",
                "type": "GeneProduct",
                "groupref": "eb9d3",
                "width": 80,
                "height": 20,
                "zorder": "33057",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000166923",
                "id": "b0bbb",
                "nodeName": "datanode",
                "x": 70.2,
                "y": 772.8,
                "label": "GREM1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "eb9d3"
            },
            {
                "graphid": "ce682",
                "type": "Pathway",
                "width": 103,
                "height": 41,
                "zorder": "33059",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP288",
                "id": "ce682",
                "nodeName": "datanode",
                "x": 878.7,
                "y": 448,
                "label": "Inflammasomeactivation",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)"
            },
            {
                "id": "a5cab",
                "x": 542.3,
                "y": 1222,
                "width": 85,
                "height": 45,
                "group": [
                    "eb3c0",
                    "a283d"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33061"
            },
            {
                "graphid": "eb3c0",
                "type": "GeneProduct",
                "groupref": "a5cab",
                "width": 80,
                "height": 20,
                "zorder": "33061",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000096696",
                "id": "eb3c0",
                "nodeName": "datanode",
                "x": 542.3,
                "y": 1212,
                "label": "DSP",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "a5cab"
            },
            {
                "graphid": "c2f1d",
                "type": "GeneProduct",
                "groupref": "dfe74",
                "width": 80,
                "height": 20,
                "zorder": "33063",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000164362",
                "id": "c2f1d",
                "nodeName": "datanode",
                "x": 907.8,
                "y": 156.3,
                "label": "TERT",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "dfe74"
            },
            {
                "graphid": "d8794",
                "type": "GeneProduct",
                "groupref": "c700d",
                "width": 80,
                "height": 20,
                "zorder": "33065",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000169057",
                "id": "d8794",
                "nodeName": "datanode",
                "x": 1008.7,
                "y": 149.2,
                "label": "MECP2",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "c700d"
            },
            {
                "graphid": "bc89e",
                "type": "GeneProduct",
                "groupref": "daaa7",
                "width": 79,
                "height": 21,
                "zorder": "33067",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000169429",
                "id": "bc89e",
                "nodeName": "datanode",
                "x": 881.6,
                "y": 968,
                "label": "CXCL8",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "a283d",
                "type": "GeneProduct",
                "groupref": "a5cab",
                "width": 79,
                "height": 20,
                "zorder": "33069",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000107960",
                "id": "a283d",
                "nodeName": "datanode",
                "x": 542.3,
                "y": 1232,
                "label": "OBFC1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "a5cab"
            },
            {
                "graphid": "dbdee",
                "type": "GeneProduct",
                "groupref": "b2b69",
                "width": 80,
                "height": 20,
                "zorder": "33071",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000110680",
                "id": "dbdee",
                "nodeName": "datanode",
                "x": 1136.9,
                "y": 799.8,
                "label": "CALCA",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "b2b69"
            },
            {
                "graphid": "fb9d6",
                "type": "GeneProduct",
                "groupref": "f76b2",
                "width": 80,
                "height": 19,
                "zorder": "33073",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000163235",
                "id": "fb9d6",
                "nodeName": "datanode",
                "x": 199.1,
                "y": 707.2,
                "label": "TGFA",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "f76b2"
            },
            {
                "graphid": "d5b1a",
                "type": "GeneProduct",
                "groupref": "e2ca2",
                "width": 79,
                "height": 20,
                "zorder": "33075",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000169194",
                "id": "d5b1a",
                "nodeName": "datanode",
                "x": 693.3,
                "y": 841.9,
                "label": "IL13",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e2ca2"
            },
            {
                "id": "bb3bc",
                "x": 684.9,
                "y": 536.8,
                "width": 135.79999999999995,
                "height": 25,
                "group": [
                    "b6702",
                    "cd2e5"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33077"
            },
            {
                "graphid": "b6702",
                "type": "GeneProduct",
                "groupref": "bb3bc",
                "width": 80,
                "height": 20,
                "zorder": "33077",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000125538",
                "id": "b6702",
                "nodeName": "datanode",
                "x": 659.5,
                "y": 536.8,
                "label": "IL1B",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "bb3bc"
            },
            {
                "graphid": "e39b2",
                "type": "GeneProduct",
                "groupref": "daaa7",
                "width": 80,
                "height": 20,
                "zorder": "33079",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000183625",
                "id": "e39b2",
                "nodeName": "datanode",
                "x": 1125.4,
                "y": 1102.5,
                "label": "CCR3",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "bfcf5",
                "type": "GeneProduct",
                "groupref": "daaa7",
                "width": 79,
                "height": 20,
                "zorder": "33081",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000271503",
                "id": "bfcf5",
                "nodeName": "datanode",
                "x": 881.6,
                "y": 988.7,
                "label": "CCL5",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "deef9",
                "type": "GeneProduct",
                "groupref": "e2ca2",
                "width": 79,
                "height": 20,
                "zorder": "33083",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000197461",
                "id": "deef9",
                "nodeName": "datanode",
                "x": 693.3,
                "y": 741.9,
                "label": "PDGFA",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e2ca2"
            },
            {
                "graphid": "ea6de",
                "type": "Pathway",
                "width": 53,
                "height": 33,
                "zorder": "33085",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP3396",
                "id": "ea6de",
                "nodeName": "datanode",
                "x": 443.7,
                "y": 460,
                "label": "NADPHoxidase",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)"
            },
            {
                "graphid": "d0320",
                "type": "GeneProduct",
                "groupref": "daaa7",
                "width": 80,
                "height": 20,
                "zorder": "33087",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000172156",
                "id": "d0320",
                "nodeName": "datanode",
                "x": 1125.4,
                "y": 1062.5,
                "label": "CCL11",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "f7c0c",
                "type": "GeneProduct",
                "groupref": "eb9d3",
                "width": 80,
                "height": 19,
                "zorder": "33089",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000068650",
                "id": "f7c0c",
                "nodeName": "datanode",
                "x": 70.2,
                "y": 792.8,
                "label": "ATP11A",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "eb9d3"
            },
            {
                "graphid": "a52cb",
                "type": "GeneProduct",
                "groupref": "bc57d",
                "width": 79,
                "height": 20,
                "zorder": "33091",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000138685",
                "id": "a52cb",
                "nodeName": "datanode",
                "x": 740.6,
                "y": 1189.6,
                "label": "FGF2",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "bc57d"
            },
            {
                "graphid": "bae9c",
                "type": "Pathway",
                "groupref": "a5cb6",
                "width": 108,
                "height": 16,
                "zorder": "33093",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP453",
                "id": "bae9c",
                "nodeName": "datanode",
                "x": 372.3,
                "y": 211,
                "label": "Inflammation",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "a5cb6"
            },
            {
                "graphid": "e1dca",
                "type": "GeneProduct",
                "width": 80,
                "height": 20,
                "zorder": "33095",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000092009",
                "id": "e1dca",
                "nodeName": "datanode",
                "x": 893,
                "y": 623.2,
                "label": "CMA1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)"
            },
            {
                "graphid": "d91aa",
                "type": "GeneProduct",
                "groupref": "e2ca2",
                "width": 79,
                "height": 20,
                "zorder": "33097",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000113525",
                "id": "d91aa",
                "nodeName": "datanode",
                "x": 693.3,
                "y": 881.9,
                "label": "IL5",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e2ca2"
            },
            {
                "graphid": "b9166",
                "type": "Pathway",
                "groupref": "a5cb6",
                "width": 154,
                "height": 22,
                "zorder": "33099",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP558",
                "id": "b9166",
                "nodeName": "datanode",
                "x": 610.2,
                "y": 212.2,
                "label": "Coagulation disturbances",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "a5cb6"
            },
            {
                "graphid": "f7a22",
                "type": "GeneProduct",
                "groupref": "bc57d",
                "width": 79,
                "height": 20,
                "zorder": "33101",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000138798",
                "id": "f7a22",
                "nodeName": "datanode",
                "x": 740.6,
                "y": 1109.6,
                "label": "EGF",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "bc57d"
            },
            {
                "graphid": "d8fb3",
                "type": "GeneProduct",
                "groupref": "db3f5",
                "width": 80,
                "height": 20,
                "zorder": "33103",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000102265",
                "id": "d8fb3",
                "nodeName": "datanode",
                "x": 499.1,
                "y": 721.2,
                "label": "TIMP1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "db3f5"
            },
            {
                "id": "f7c1d",
                "x": 384.6,
                "y": 442.8,
                "width": 87,
                "height": 48.39999999999998,
                "group": [
                    "eddfc",
                    "ca941"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33105"
            },
            {
                "graphid": "eddfc",
                "type": "Pathway",
                "groupref": "f7c1d",
                "width": 45,
                "height": 19,
                "zorder": "33105",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "KEGG Pathway : hsa04064",
                "id": "eddfc",
                "nodeName": "datanode",
                "x": 382.7,
                "y": 455,
                "label": "NF-KB",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "f7c1d"
            },
            {
                "graphid": "fada0",
                "type": "GeneProduct",
                "groupref": "e2ca2",
                "width": 79,
                "height": 20,
                "zorder": "33107",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000113302",
                "id": "fada0",
                "nodeName": "datanode",
                "x": 693.3,
                "y": 821.9,
                "label": "IL12B",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e2ca2"
            },
            {
                "graphid": "c98db",
                "type": "GeneProduct",
                "groupref": "d9cec",
                "width": 79,
                "height": 20,
                "zorder": "33109",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000101144",
                "id": "c98db",
                "nodeName": "datanode",
                "x": 540.2,
                "y": 1331.8,
                "label": "BMP7",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "d9cec"
            },
            {
                "id": "d375c",
                "x": 783.45,
                "y": 614.35,
                "width": 89.30000000000007,
                "height": 41.700000000000045,
                "group": [
                    "f3648",
                    "f6f3b"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33111"
            },
            {
                "graphid": "f3648",
                "type": "GeneProduct",
                "groupref": "d375c",
                "width": 80,
                "height": 20,
                "zorder": "33111",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000100311",
                "id": "f3648",
                "nodeName": "datanode",
                "x": 785.6,
                "y": 622.7,
                "label": "PDGFB",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "d375c"
            },
            {
                "graphid": "df04d",
                "type": "GeneProduct",
                "groupref": "d9cec",
                "width": 79,
                "height": 20,
                "zorder": "33113",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000163661",
                "id": "df04d",
                "nodeName": "datanode",
                "x": 540.2,
                "y": 1391.8,
                "label": "PTX3",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "d9cec"
            },
            {
                "graphid": "bee91",
                "type": "GeneProduct",
                "groupref": "f358b",
                "width": 79,
                "height": 20,
                "zorder": "33115",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000116044",
                "id": "bee91",
                "nodeName": "datanode",
                "x": 1288.6,
                "y": 1099.4,
                "label": "NFE2L2",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "f358b"
            },
            {
                "graphid": "f0f62",
                "type": "GeneProduct",
                "groupref": "db3f5",
                "width": 79,
                "height": 20,
                "zorder": "33117",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000100985",
                "id": "f0f62",
                "nodeName": "datanode",
                "x": 499.1,
                "y": 681.2,
                "label": "MMP9",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "db3f5"
            },
            {
                "graphid": "d31d4",
                "type": "GeneProduct",
                "groupref": "bc57d",
                "width": 79,
                "height": 20,
                "zorder": "33119",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000140285",
                "id": "d31d4",
                "nodeName": "datanode",
                "x": 740.6,
                "y": 1209.6,
                "label": "FGF7",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "bc57d"
            },
            {
                "graphid": "b96f2",
                "type": "GeneProduct",
                "groupref": "bda4a",
                "width": 80,
                "height": 20,
                "zorder": "33121",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000117983",
                "id": "b96f2",
                "nodeName": "datanode",
                "x": 1008.3,
                "y": 209.6,
                "label": "MUC5B",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "bda4a"
            },
            {
                "graphid": "ca8a4",
                "type": "GeneProduct",
                "groupref": "b2b69",
                "width": 80,
                "height": 20,
                "zorder": "33123",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000172216",
                "id": "ca8a4",
                "nodeName": "datanode",
                "x": 1136.9,
                "y": 819.8,
                "label": "CEBPB",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "b2b69"
            },
            {
                "graphid": "fb0bc",
                "type": "GeneProduct",
                "groupref": "e1c3b",
                "width": 81,
                "height": 20,
                "zorder": "33125",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000152207",
                "id": "fb0bc",
                "nodeName": "datanode",
                "x": 1291,
                "y": 855.6,
                "label": "CYSLTR2",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e1c3b"
            },
            {
                "graphid": "ae474",
                "type": "GeneProduct",
                "groupref": "f358b",
                "width": 79,
                "height": 20,
                "zorder": "33127",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000100292",
                "id": "ae474",
                "nodeName": "datanode",
                "x": 1288.6,
                "y": 1119.4,
                "label": "HMOX1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "f358b"
            },
            {
                "id": "a4d4a",
                "x": 150.6,
                "y": 442.75,
                "width": 114.19999999999999,
                "height": 40.5,
                "group": [
                    "cc38a",
                    "b823a"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33129"
            },
            {
                "graphid": "cc38a",
                "type": "Pathway",
                "groupref": "a4d4a",
                "width": 63,
                "height": 30,
                "zorder": "33129",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP400",
                "id": "cc38a",
                "nodeName": "datanode",
                "x": 173.7,
                "y": 445.5,
                "label": "p38 MAPK",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "a4d4a"
            },
            {
                "graphid": "eb6f5",
                "type": "GeneProduct",
                "groupref": "db3f5",
                "width": 79,
                "height": 20,
                "zorder": "33131",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000087245",
                "id": "eb6f5",
                "nodeName": "datanode",
                "x": 499.1,
                "y": 701.2,
                "label": "MMP2",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "db3f5"
            },
            {
                "graphid": "efb4d",
                "type": "GeneProduct",
                "groupref": "bc57d",
                "width": 79,
                "height": 20,
                "zorder": "33133",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000019991",
                "id": "efb4d",
                "nodeName": "datanode",
                "x": 740.6,
                "y": 1149.6,
                "label": "HGF",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "bc57d"
            },
            {
                "graphid": "d7cbe",
                "type": "GeneProduct",
                "groupref": "e0f0a",
                "width": 80,
                "height": 20,
                "zorder": "33135",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000168484",
                "id": "d7cbe",
                "nodeName": "datanode",
                "x": 936.1,
                "y": 808.2,
                "label": "SFTPC",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e0f0a"
            },
            {
                "graphid": "f95b1",
                "type": "GeneProduct",
                "groupref": "daaa7",
                "width": 80,
                "height": 20,
                "zorder": "33137",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000121807",
                "id": "f95b1",
                "nodeName": "datanode",
                "x": 1125.4,
                "y": 1082.5,
                "label": "CCR2",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "dfac1",
                "type": "GeneProduct",
                "groupref": "e2ca2",
                "width": 79,
                "height": 20,
                "zorder": "33139",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000113520",
                "id": "dfac1",
                "nodeName": "datanode",
                "x": 693.3,
                "y": 861.9,
                "label": "IL4",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e2ca2"
            },
            {
                "graphid": "b835e",
                "type": "GeneProduct",
                "groupref": "e2ca2",
                "width": 79,
                "height": 20,
                "zorder": "33141",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000164400",
                "id": "b835e",
                "nodeName": "datanode",
                "x": 693.3,
                "y": 801.9,
                "label": "CSF2",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e2ca2"
            },
            {
                "graphid": "cdc29",
                "type": "GeneProduct",
                "groupref": "d9cec",
                "width": 79,
                "height": 20,
                "zorder": "33145",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000122861",
                "id": "cdc29",
                "nodeName": "datanode",
                "x": 540.2,
                "y": 1371.8,
                "label": "PLAU",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "d9cec"
            },
            {
                "graphid": "d0c59",
                "type": "GeneProduct",
                "groupref": "e1c3b",
                "width": 81,
                "height": 20,
                "zorder": "33147",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000138640",
                "id": "d0c59",
                "nodeName": "datanode",
                "x": 1291,
                "y": 875.6,
                "label": "FAM13A",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e1c3b"
            },
            {
                "graphid": "c74c5",
                "type": "GeneProduct",
                "groupref": "daaa7",
                "width": 79,
                "height": 20,
                "zorder": "33149",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000277632",
                "id": "c74c5",
                "nodeName": "datanode",
                "x": 881.6,
                "y": 1029.9,
                "label": "CCL3",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "c6375",
                "type": "GeneProduct",
                "width": 80,
                "height": 20,
                "zorder": "33151",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000125148",
                "id": "c6375",
                "nodeName": "datanode",
                "x": 300.2,
                "y": 746.8,
                "label": "MT2A",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)"
            },
            {
                "graphid": "b9253",
                "type": "GeneProduct",
                "groupref": "bc57d",
                "width": 79,
                "height": 20,
                "zorder": "33153",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000017427",
                "id": "b9253",
                "nodeName": "datanode",
                "x": 740.6,
                "y": 1129.6,
                "label": "IGF1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "bc57d"
            },
            {
                "id": "e1607",
                "x": 387.35,
                "y": 586.9000000000001,
                "width": 88.30000000000001,
                "height": 44.60000000000002,
                "group": [
                    "eb255",
                    "f900c"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33155"
            },
            {
                "graphid": "eb255",
                "type": "GeneProduct",
                "groupref": "e1607",
                "width": 77,
                "height": 20,
                "zorder": "33155",
                "fontsize": "10",
                "valign": "Middle",
                "database": "Ensembl : ENSG00000105329",
                "id": "eb255",
                "nodeName": "datanode",
                "x": 384.2,
                "y": 596.7,
                "label": "TGFB1",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgb(0,0,0)",
                "parentNode": "e1607"
            },
            {
                "id": "d12de",
                "x": 274.5,
                "y": 453.8,
                "width": 69,
                "height": 48.60000000000002,
                "group": [
                    "eedc0",
                    "b003d"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33159"
            },
            {
                "graphid": "eedc0",
                "type": "Metabolite",
                "groupref": "d12de",
                "width": 64,
                "height": 24,
                "zorder": "33159",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "ChEBI : CHEBI:26523",
                "id": "eedc0",
                "nodeName": "datanode",
                "x": 274.5,
                "y": 444,
                "label": "ROSproduction",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,255)",
                "outline": "rgb(0,0,255)",
                "parentNode": "d12de"
            },
            {
                "graphid": "bfca5",
                "width": 332,
                "height": 24,
                "zorder": "33161",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 962.1,
                "y": 86,
                "label": "Additional non-connected genes with direct association topulmonary fibrosis in the Comparative Toxicogenomics Database (CTD)",
                "id": "bfca5",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "fcf77",
                "width": 332,
                "height": 24,
                "zorder": "33163",
                "fontsize": "10",
                "valign": "Middle",
                "nodeName": "label",
                "x": 505.5,
                "y": 77.8,
                "label": "All genes in the network are directly associated withpulmonary fibrosis in the Comparative Toxicogenomics Database (CTD)",
                "id": "fcf77",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "id": "a81f8",
                "x": 514.6,
                "y": 462.15,
                "width": 59.799999999999955,
                "height": 45.69999999999999,
                "group": [
                    "d7534",
                    "f032d"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33165"
            },
            {
                "graphid": "d7534",
                "type": "Metabolite",
                "groupref": "a81f8",
                "width": 51,
                "height": 21,
                "zorder": "33165",
                "fontsize": "10",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "ChEBI : CHEBI:26523",
                "id": "d7534",
                "nodeName": "datanode",
                "x": 512.7,
                "y": 452.3,
                "label": "ROSproduction",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,255)",
                "outline": "rgb(0,0,255)",
                "parentNode": "a81f8"
            },
            {
                "id": "cb74d",
                "x": 691.2,
                "y": 441.85,
                "width": 87,
                "height": 40.30000000000001,
                "group": [
                    "e6fda",
                    "c0bc5"
                ],
                "hideLabel": True,
                "hideTooltip": False,
                "type": "Group",
                "color": "rgba(245,245,245,0.5)",
                "outline": "rgb(0,0,0)",
                "shape": "rectangle",
                "zorder": "33167"
            },
            {
                "graphid": "e6fda",
                "type": "Pathway",
                "groupref": "cb74d",
                "width": 45,
                "height": 25,
                "zorder": "33167",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "KEGG Pathway : hsa04064",
                "id": "e6fda",
                "nodeName": "datanode",
                "x": 689.3,
                "y": 447,
                "label": "NF-KB",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "cb74d"
            },
            {
                "graphid": "c0bc5",
                "groupref": "cb74d",
                "width": 82,
                "height": 17,
                "zorder": "33168",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 691.2,
                "y": 432.7,
                "label": "KE1/KE2",
                "id": "c0bc5",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "cb74d"
            },
            {
                "graphid": "e5386",
                "type": "Pathway",
                "width": 103,
                "height": 41,
                "zorder": "33169",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP288",
                "id": "e5386",
                "nodeName": "datanode",
                "x": 603.8,
                "y": 453,
                "label": "Inflammasomeactivation",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)"
            },
            {
                "graphid": "cd2e5",
                "groupref": "bb3bc",
                "width": 47,
                "height": 14,
                "zorder": "33171",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 726.8,
                "y": 534.5,
                "label": "KE1",
                "id": "cd2e5",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "bb3bc"
            },
            {
                "graphid": "d37a4",
                "groupref": "e2ca2",
                "width": 80,
                "height": 10,
                "zorder": "33173",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 690.3,
                "y": 934.9,
                "label": "KE1/KE3",
                "id": "d37a4",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "e2ca2"
            },
            {
                "graphid": "f8ed1",
                "groupref": "daaa7",
                "width": 79,
                "height": 9,
                "zorder": "33175",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1136.4,
                "y": 933,
                "label": "KE1/KE3",
                "id": "f8ed1",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "ca941",
                "groupref": "f7c1d",
                "width": 82,
                "height": 17,
                "zorder": "33177",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 384.6,
                "y": 429.6,
                "label": "KE1/KE2",
                "id": "ca941",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "f7c1d"
            },
            {
                "graphid": "b6351",
                "groupref": "bc57d",
                "width": 80,
                "height": 9,
                "zorder": "33179",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 736.1,
                "y": 1244,
                "label": "KE3/KE4",
                "id": "b6351",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "bc57d"
            },
            {
                "graphid": "c5c8c",
                "groupref": "d8be9",
                "width": 79,
                "height": 9,
                "zorder": "33181",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 544,
                "y": 1006,
                "label": "KE3",
                "id": "c5c8c",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "d8be9"
            },
            {
                "graphid": "f900c",
                "groupref": "e1607",
                "width": 79,
                "height": 9,
                "zorder": "33183",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 389.5,
                "y": 571.6,
                "label": "KE3/KE4",
                "id": "f900c",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "e1607"
            },
            {
                "graphid": "bf6c8",
                "groupref": "b2b69",
                "width": 79,
                "height": 9,
                "zorder": "33185",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1131.9,
                "y": 842.3,
                "label": "KE3",
                "id": "bf6c8",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "b2b69"
            },
            {
                "graphid": "b823a",
                "groupref": "a4d4a",
                "width": 79,
                "height": 9,
                "zorder": "33187",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 135.5,
                "y": 429.5,
                "label": "KE4",
                "id": "b823a",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "a4d4a"
            },
            {
                "graphid": "d9434",
                "groupref": "a3a34",
                "width": 79,
                "height": 9,
                "zorder": "33189",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 811.7,
                "y": 421.2,
                "label": "KE4",
                "id": "d9434",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "a3a34"
            },
            {
                "graphid": "e5051",
                "groupref": "cb3c3",
                "width": 80,
                "height": 9,
                "zorder": "33191",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 347.6,
                "y": 1341.9,
                "label": "KE5",
                "id": "e5051",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "cb3c3"
            },
            {
                "graphid": "b5376",
                "groupref": "c63cd",
                "width": 54,
                "height": 9,
                "zorder": "33193",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 347.6,
                "y": 1441.1,
                "label": "AO",
                "id": "b5376",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "c63cd"
            },
            {
                "graphid": "f032d",
                "groupref": "a81f8",
                "width": 47,
                "height": 14,
                "zorder": "33197",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 518.5,
                "y": 475.5,
                "label": "AE1",
                "id": "f032d",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "a81f8"
            },
            {
                "graphid": "b003d",
                "groupref": "d12de",
                "width": 47,
                "height": 14,
                "zorder": "33199",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 273.6,
                "y": 468.6,
                "label": "AE1",
                "id": "b003d",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "d12de"
            },
            {
                "graphid": "ed142",
                "groupref": "f358b",
                "width": 47,
                "height": 14,
                "zorder": "33201",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1263.7,
                "y": 1164.4,
                "label": "AE1",
                "id": "ed142",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "f358b"
            },
            {
                "graphid": "e508c",
                "groupref": "daaa7",
                "width": 47,
                "height": 13,
                "zorder": "33203",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1013.2,
                "y": 1123,
                "label": "AE2",
                "id": "e508c",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "e5ae2",
                "groupref": "d9cec",
                "width": 47,
                "height": 14,
                "zorder": "33205",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 537,
                "y": 1420.7,
                "label": "AE1",
                "id": "e5ae2",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "d9cec"
            },
            {
                "graphid": "f6f3b",
                "groupref": "d375c",
                "width": 80,
                "height": 9,
                "zorder": "33207",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 781.3,
                "y": 600.5,
                "label": "KE3/KE4",
                "id": "f6f3b",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "d375c"
            },
            {
                "graphid": "dcf46",
                "groupref": "e7c4b",
                "width": 80,
                "height": 9,
                "zorder": "33209",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 129.2,
                "y": 732.9,
                "label": "KE3/KE4",
                "id": "dcf46",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "e7c4b"
            },
            {
                "graphid": "ee82d",
                "groupref": "db3f5",
                "width": 79,
                "height": 9,
                "zorder": "33211",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 498.3,
                "y": 748.3,
                "label": "KE3",
                "id": "ee82d",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "db3f5"
            },
            {
                "graphid": "eced8",
                "width": 394,
                "height": 56,
                "zorder": "33213",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1377.4,
                "y": 179,
                "label": "Events related to a putative Adverse Outcome Pathway forpulmonary fibrosis",
                "id": "eced8",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "df75e",
                "width": 89,
                "height": 30,
                "zorder": "33215",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 1213.6,
                "y": 146.8,
                "label": "Legend",
                "id": "df75e",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "graphid": "c8e45",
                "type": "Pathway",
                "groupref": "daaa7",
                "width": 109,
                "height": 35,
                "zorder": "33217",
                "fontweight": "Bold",
                "fontsize": "12",
                "valign": "Middle",
                "color": "rgba(0,0,0,0)",
                "database": "WikiPathways : WP75",
                "id": "c8e45",
                "nodeName": "datanode",
                "x": 882.6,
                "y": 940.8,
                "label": "Toll-like receptorsignaling",
                "labelSize": 12,
                "shape": "rectangle",
                "labelColor": "rgb(20,150,30)",
                "outline": "rgb(20,150,30)",
                "parentNode": "daaa7"
            },
            {
                "graphid": "c0b1d",
                "groupref": "fff69",
                "width": 47,
                "height": 14,
                "zorder": "33225",
                "fontname": "Arial Black",
                "fontweight": "Bold",
                "fontsize": "14",
                "valign": "Middle",
                "nodeName": "label",
                "x": 347.5,
                "y": 1207.8,
                "label": "AE3",
                "id": "c0b1d",
                "labelSize": 14,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "parentNode": "fff69"
            },
            {
                "graphid": "e608e",
                "width": 380,
                "height": 20,
                "zorder": "33226",
                "fontsize": "10",
                "valign": "Middle",
                "align": "Left",
                "nodeName": "label",
                "x": 1371.1,
                "y": 354.2,
                "label": "AE3 - Collagen production",
                "id": "e608e",
                "labelSize": 10,
                "shape": "rectangle",
                "labelColor": "rgb(0,0,0)",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)"
            },
            {
                "id": "b0d50",
                "x": 498.4,
                "y": 260.9,
                "width": 1,
                "height": 1,
                "hideLabel": True,
                "hideTooltip": False,
                "eventless": True,
                "type": "Anchor",
                "color": "rgba(0,0,0,0)",
                "outline": "rgba(0,0,0,0)",
                "shape": "circle",
                "zorder": 0
            }
        ],
        "edges": [
            {
                "graphid": "b71ee",
                "connectortype": "Elbow",
                "zorder": "32835",
                "point": [
                    {
                        "x": "498.46153846153925",
                        "y": "383.7948717948722",
                        "graphref": "d4612",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "512.7261590764999",
                        "y": "441.79487179487234",
                        "graphref": "d7534",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d4612",
                "id2": "d7534",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        498.5,
                        383.8
                    ],
                    [
                        498.5,
                        403.8
                    ],
                    [
                        512.7,
                        403.8
                    ],
                    [
                        512.7,
                        441.8
                    ]
                ]
            },
            {
                "graphid": "ab5b4",
                "zorder": "32837",
                "point": [
                    {
                        "x": "347.598290760959",
                        "y": "1232.1217267306197",
                        "graphref": "b02c7",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "347.5982907609591",
                        "y": "1289.1819636316052",
                        "graphref": "a4170",
                        "relx": "0.0",
                        "rely": "-1.0",
                        "arrowhead": "Arrow"
                    }
                ],
                "nodeName": "interaction",
                "id1": "fff69",
                "id2": "cb3c3",
                "type": "solid",
                "endArrow": "arrow",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1
            },
            {
                "graphid": "fae2d",
                "connectortype": "Elbow",
                "zorder": "32839",
                "point": [
                    {
                        "x": "580.2236203471323",
                        "y": "1371.822804386678",
                        "graphref": "cdc29",
                        "relx": "1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "637.7948717948725",
                        "y": "1260.6944948527807"
                    },
                    {
                        "x": "700.551904068885",
                        "y": "1149.5661853188833",
                        "graphref": "efb4d",
                        "relx": "-1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "cdc29",
                "id2": "efb4d",
                "type": "solid",
                "thickness": 1,
                "startX": 1,
                "startY": 0,
                "endX": -1,
                "endY": 0,
                "elbows": [
                    [
                        580.2,
                        1371.8
                    ],
                    [
                        637.8,
                        1371.8
                    ],
                    [
                        637.8,
                        1149.6
                    ],
                    [
                        700.6,
                        1149.6
                    ]
                ]
            },
            {
                "graphid": "fa16e",
                "connectortype": "Elbow",
                "zorder": "32841",
                "point": [
                    {
                        "x": "645.2115384615392",
                        "y": "383.7948717948722",
                        "graphref": "fb58a",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "878.711538461539",
                        "y": "427.29487179487234",
                        "graphref": "ce682",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "fb58a",
                "id2": "ce682",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        645.2,
                        383.8
                    ],
                    [
                        645.2,
                        403.8
                    ],
                    [
                        878.7,
                        403.8
                    ],
                    [
                        878.7,
                        427.3
                    ]
                ]
            },
            {
                "graphid": "cf0e1",
                "connectortype": "Elbow",
                "zorder": "32843",
                "point": [
                    {
                        "x": "364.84476303196993",
                        "y": "606.7476755152276",
                        "graphref": "eb255",
                        "relx": "-0.5",
                        "rely": "1.0"
                    },
                    {
                        "x": "281.97869206747987",
                        "y": "626.7948717948724"
                    },
                    {
                        "x": "199.11262110298986",
                        "y": "669.1834048260207",
                        "graphref": "e83b2",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "eb255",
                "id2": "f76b2",
                "type": "solid",
                "thickness": 1,
                "startX": -0.5,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        364.8,
                        606.7
                    ],
                    [
                        364.8,
                        626.8
                    ],
                    [
                        199.1,
                        626.8
                    ],
                    [
                        199.1,
                        669.2
                    ]
                ]
            },
            {
                "graphid": "d69a7",
                "connectortype": "Elbow",
                "zorder": "32845",
                "point": [
                    {
                        "x": "611.3032652799227",
                        "y": "962.2869311463703",
                        "graphref": "ee899",
                        "relx": "1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "653.2684853188848",
                        "y": "821.8550306332402",
                        "graphref": "fada0",
                        "relx": "-1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "ee899",
                "id2": "fada0",
                "type": "solid",
                "thickness": 1,
                "startX": 1,
                "startY": 0,
                "endX": -1,
                "endY": 0,
                "elbows": [
                    [
                        611.3,
                        962.3
                    ],
                    [
                        631.3,
                        962.3
                    ],
                    [
                        631.3,
                        821.9
                    ],
                    [
                        653.3,
                        821.9
                    ]
                ]
            },
            {
                "graphid": "f467b",
                "connectortype": "Elbow",
                "zorder": "32847",
                "point": [
                    {
                        "x": "173.71153846153854",
                        "y": "460.79487179487234",
                        "graphref": "cc38a",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "345.5324915131929",
                        "y": "596.7476755152276",
                        "graphref": "eb255",
                        "relx": "-1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "cc38a",
                "id2": "eb255",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": -1,
                "endY": 0,
                "elbows": [
                    [
                        173.7,
                        460.8
                    ],
                    [
                        173.7,
                        596.7
                    ],
                    [
                        345.5,
                        596.7
                    ]
                ]
            },
            {
                "graphid": "c4d4c",
                "connectortype": "Elbow",
                "zorder": "32849",
                "point": [
                    {
                        "x": "580.2236203471323",
                        "y": "1391.822804386678",
                        "graphref": "df04d",
                        "relx": "1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "652.4615384615392",
                        "y": "1290.6944948527807"
                    },
                    {
                        "x": "700.551904068885",
                        "y": "1189.5661853188833",
                        "graphref": "a52cb",
                        "relx": "-1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "df04d",
                "id2": "a52cb",
                "type": "solid",
                "thickness": 1,
                "startX": 1,
                "startY": 0,
                "endX": -1,
                "endY": 0,
                "elbows": [
                    [
                        580.2,
                        1391.8
                    ],
                    [
                        652.5,
                        1391.8
                    ],
                    [
                        652.5,
                        1189.6
                    ],
                    [
                        700.6,
                        1189.6
                    ]
                ]
            },
            {
                "graphid": "bf483",
                "connectortype": "Elbow",
                "zorder": "32851",
                "point": [
                    {
                        "x": "645.2115384615392",
                        "y": "383.7948717948722",
                        "graphref": "fb58a",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "689.2752568461194",
                        "y": "434.29487179487234",
                        "graphref": "e6fda",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "fb58a",
                "id2": "e6fda",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        645.2,
                        383.8
                    ],
                    [
                        645.2,
                        403.8
                    ],
                    [
                        689.3,
                        403.8
                    ],
                    [
                        689.3,
                        434.3
                    ]
                ]
            },
            {
                "graphid": "fd836",
                "connectortype": "Elbow",
                "zorder": "32853",
                "point": [
                    {
                        "x": "498.46153846153925",
                        "y": "383.7948717948722",
                        "graphref": "d4612",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "382.7115384615392",
                        "y": "445.29487179487234",
                        "graphref": "eddfc",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d4612",
                "id2": "eddfc",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        498.5,
                        383.8
                    ],
                    [
                        498.5,
                        403.8
                    ],
                    [
                        382.7,
                        403.8
                    ],
                    [
                        382.7,
                        445.3
                    ]
                ]
            },
            {
                "graphid": "d7704",
                "groupref": "daaa7",
                "connectortype": "Elbow",
                "zorder": "32855",
                "point": [
                    {
                        "x": "1053.7343365744518",
                        "y": "1027.7317413181195",
                        "graphref": "d8e39",
                        "relx": "1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "1125.030888423737",
                        "y": "1046.325106110818",
                        "graphref": "b1aab",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d8e39",
                "id2": "b1aab",
                "type": "solid",
                "thickness": 1,
                "startX": 1,
                "startY": 0,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        1053.7,
                        1027.7
                    ],
                    [
                        1125,
                        1027.7
                    ],
                    [
                        1125,
                        1046.3
                    ]
                ]
            },
            {
                "graphid": "fc043",
                "connectortype": "Elbow",
                "zorder": "32857",
                "point": [
                    {
                        "x": "571.3032652799227",
                        "y": "992.2869311463704",
                        "graphref": "e6d9c",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "700.5519040688853",
                        "y": "1129.5661853188833",
                        "graphref": "b9253",
                        "relx": "-1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "e6d9c",
                "id2": "b9253",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": -1,
                "endY": 0,
                "elbows": [
                    [
                        571.3,
                        992.3
                    ],
                    [
                        571.3,
                        1129.6
                    ],
                    [
                        700.6,
                        1129.6
                    ]
                ]
            },
            {
                "graphid": "e8f82",
                "zorder": "32859",
                "point": [
                    {
                        "x": "470.4615384615392",
                        "y": "451.66987179487234",
                        "graphref": "ea6de",
                        "relx": "1.0",
                        "rely": "-0.5"
                    },
                    {
                        "x": "487.2261590764999",
                        "y": "452.29487179487234",
                        "graphref": "d7534",
                        "relx": "-1.0",
                        "rely": "0.0",
                        "arrowhead": "Arrow"
                    }
                ],
                "nodeName": "interaction",
                "id1": "ea6de",
                "id2": "d7534",
                "type": "solid",
                "endArrow": "arrow",
                "thickness": 1,
                "startX": 1,
                "startY": -0.5,
                "endX": -1,
                "endY": 0
            },
            {
                "graphid": "c8f1e",
                "connectortype": "Elbow",
                "zorder": "32861",
                "point": [
                    {
                        "x": "1328.5834174010513",
                        "y": "1139.4440001987116",
                        "graphref": "d01e0",
                        "relx": "1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "1375.2360699282713",
                        "y": "1205.9001629933073",
                        "graphref": "c28e9",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d01e0",
                "id2": "b8425",
                "type": "solid",
                "thickness": 1,
                "startX": 1,
                "startY": 0,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        1328.6,
                        1139.4
                    ],
                    [
                        1375.2,
                        1139.4
                    ],
                    [
                        1375.2,
                        1205.9
                    ]
                ]
            },
            {
                "graphid": "d4553",
                "zorder": "32863",
                "point": [
                    {
                        "x": "498.2210665922105",
                        "y": "166.7948717948717",
                        "graphref": "d01e4",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "496.9643424542787",
                        "y": "187.7948717948719",
                        "graphref": "bbd47",
                        "relx": "0.0",
                        "rely": "-1.0",
                        "arrowhead": "Arrow"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d01e4",
                "id2": "ee465",
                "type": "solid",
                "endArrow": "arrow",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1
            },
            {
                "graphid": "eb517",
                "connectortype": "Elbow",
                "zorder": "32865",
                "point": [
                    {
                        "x": "645.2115384615392",
                        "y": "383.7948717948722",
                        "graphref": "fb58a",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "787.2115384615388",
                        "y": "428.29487179487234",
                        "graphref": "cc748",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "fb58a",
                "id2": "cc748",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        645.2,
                        383.8
                    ],
                    [
                        645.2,
                        403.8
                    ],
                    [
                        787.2,
                        403.8
                    ],
                    [
                        787.2,
                        428.3
                    ]
                ]
            },
            {
                "graphid": "c7fdc",
                "connectortype": "Elbow",
                "zorder": "32867",
                "point": [
                    {
                        "x": "603.8200384615386",
                        "y": "473.79487179487234",
                        "graphref": "e5386",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "659.5422487117385",
                        "y": "526.8279629974546",
                        "graphref": "b6702",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "e5386",
                "id2": "b6702",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        603.8,
                        473.8
                    ],
                    [
                        603.8,
                        493.8
                    ],
                    [
                        659.5,
                        493.8
                    ],
                    [
                        659.5,
                        526.8
                    ]
                ]
            },
            {
                "graphid": "aaef8",
                "connectortype": "Elbow",
                "zorder": "32869",
                "point": [
                    {
                        "x": "805.5683371903531",
                        "y": "632.71970300956",
                        "graphref": "f3648",
                        "relx": "0.5",
                        "rely": "1.0"
                    },
                    {
                        "x": "892.9999783751592",
                        "y": "670.00637161311",
                        "graphref": "ecb8e",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "f3648",
                "id2": "ecb8e",
                "type": "solid",
                "thickness": 1,
                "startX": 0.5,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        805.6,
                        632.7
                    ],
                    [
                        805.6,
                        652.7
                    ],
                    [
                        893,
                        652.7
                    ],
                    [
                        893,
                        670
                    ]
                ]
            },
            {
                "graphid": "f50b9",
                "zorder": "32871",
                "point": [
                    {
                        "x": "347.5982907609591",
                        "y": "1360.8069636316056",
                        "graphref": "a4170",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "347.598290760959",
                        "y": "1410.8107175681725",
                        "graphref": "bd9df",
                        "relx": "0.0",
                        "rely": "-1.0",
                        "arrowhead": "Arrow"
                    }
                ],
                "nodeName": "interaction",
                "id1": "cb3c3",
                "id2": "c63cd",
                "type": "solid",
                "endArrow": "arrow",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1
            },
            {
                "graphid": "ee1f8",
                "zorder": "32873",
                "point": [
                    {
                        "x": "496.9643424542787",
                        "y": "226.7948717948719",
                        "graphref": "c5ee0",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "498.4115384615389",
                        "y": "260.9055795988649",
                        "graphref": "b0d50",
                        "relx": "0.0",
                        "rely": "0.0",
                        "arrowhead": "Arrow"
                    }
                ],
                "nodeName": "interaction",
                "id1": "c5ee0",
                "id2": "b0d50",
                "type": "solid",
                "endArrow": "arrow",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": 0,
                "hideTooltip": False,
                "exactEnd": True
            },
            {
                "graphid": "e0975",
                "connectortype": "Elbow",
                "zorder": "32875",
                "point": [
                    {
                        "x": "159.11262110298992",
                        "y": "707.1834048260207",
                        "graphref": "fb9d6",
                        "relx": "-1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "70.1620608800126",
                        "y": "754.8088693857343",
                        "graphref": "ca264",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "fb9d6",
                "id2": "eb9d3",
                "type": "solid",
                "thickness": 1,
                "startX": -1,
                "startY": 0,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        159.1,
                        707.2
                    ],
                    [
                        70.2,
                        707.2
                    ],
                    [
                        70.2,
                        754.8
                    ]
                ]
            },
            {
                "graphid": "bc86c",
                "connectortype": "Elbow",
                "zorder": "32877",
                "point": [
                    {
                        "x": "679.5422487117385",
                        "y": "546.8279629974546",
                        "graphref": "b6702",
                        "relx": "0.5",
                        "rely": "1.0"
                    },
                    {
                        "x": "892.9706995137996",
                        "y": "613.1844106366775",
                        "graphref": "e1dca",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "b6702",
                "id2": "e1dca",
                "type": "solid",
                "thickness": 1,
                "startX": 0.5,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        679.5,
                        546.8
                    ],
                    [
                        679.5,
                        566.8
                    ],
                    [
                        893,
                        566.8
                    ],
                    [
                        893,
                        613.2
                    ]
                ]
            },
            {
                "graphid": "aecb1",
                "connectortype": "Elbow",
                "zorder": "32879",
                "point": [
                    {
                        "x": "679.5422487117385",
                        "y": "546.8279629974546",
                        "graphref": "b6702",
                        "relx": "0.5",
                        "rely": "1.0"
                    },
                    {
                        "x": "785.5683371903531",
                        "y": "612.71970300956",
                        "graphref": "f3648",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "b6702",
                "id2": "f3648",
                "type": "solid",
                "thickness": 1,
                "startX": 0.5,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        679.5,
                        546.8
                    ],
                    [
                        679.5,
                        566.8
                    ],
                    [
                        785.6,
                        566.8
                    ],
                    [
                        785.6,
                        612.7
                    ]
                ]
            },
            {
                "graphid": "acede",
                "connectortype": "Elbow",
                "zorder": "32881",
                "point": [
                    {
                        "x": "659.5422487117385",
                        "y": "546.8279629974546",
                        "graphref": "b6702",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "422.78157758830116",
                        "y": "596.7476755152276",
                        "graphref": "eb255",
                        "relx": "1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "b6702",
                "id2": "eb255",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 1,
                "endY": 0,
                "elbows": [
                    [
                        659.5,
                        546.8
                    ],
                    [
                        659.5,
                        596.7
                    ],
                    [
                        422.8,
                        596.7
                    ]
                ]
            },
            {
                "graphid": "aa54f",
                "connectortype": "Elbow",
                "zorder": "32883",
                "point": [
                    {
                        "x": "260.2055644855511",
                        "y": "746.8255703387243",
                        "graphref": "c6375",
                        "relx": "-1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "227.89804639804726",
                        "y": "790.4198717948718",
                        "graphref": "de9f1",
                        "relx": "1.0",
                        "rely": "0.5"
                    }
                ],
                "nodeName": "interaction",
                "id1": "c6375",
                "id2": "de9f1",
                "type": "solid",
                "thickness": 1,
                "startX": -1,
                "startY": 0,
                "endX": 1,
                "endY": 0.5,
                "elbows": [
                    [
                        260.2,
                        746.8
                    ],
                    [
                        240.2,
                        746.8
                    ],
                    [
                        240.2,
                        790.4
                    ],
                    [
                        227.9,
                        790.4
                    ]
                ]
            },
            {
                "graphid": "a95ab",
                "connectortype": "Elbow",
                "zorder": "32885",
                "point": [
                    {
                        "x": "353.9615384615389",
                        "y": "293.7948717948722",
                        "graphref": "f309d",
                        "relx": "0.0",
                        "rely": "-1.0"
                    },
                    {
                        "x": "499.5865384615391",
                        "y": "260.9055795988649"
                    },
                    {
                        "x": "645.2115384615392",
                        "y": "293.7948717948722",
                        "graphref": "fb58a",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "f309d",
                "id2": "fb58a",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": -1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        354,
                        293.8
                    ],
                    [
                        354,
                        260.9
                    ],
                    [
                        645.2,
                        260.9
                    ],
                    [
                        645.2,
                        293.8
                    ]
                ]
            },
            {
                "graphid": "ad9c4",
                "connectortype": "Elbow",
                "zorder": "32887",
                "point": [
                    {
                        "x": "892.9999783751592",
                        "y": "690.00637161311",
                        "graphref": "ecb8e",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "939.6755907491242",
                        "y": "726.1662870276311",
                        "graphref": "d318a",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "ecb8e",
                "id2": "d318a",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        893,
                        690
                    ],
                    [
                        893,
                        710
                    ],
                    [
                        939.7,
                        710
                    ],
                    [
                        939.7,
                        726.2
                    ]
                ]
            },
            {
                "graphid": "ae395",
                "zorder": "32889",
                "point": [
                    {
                        "x": "712.0252568461194",
                        "y": "447.04487179487234",
                        "graphref": "e6fda",
                        "relx": "1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "757.9615384615388",
                        "y": "446.54487179487234",
                        "graphref": "cc748",
                        "relx": "-1.0",
                        "rely": "0.0",
                        "arrowhead": "Arrow"
                    }
                ],
                "nodeName": "interaction",
                "id1": "e6fda",
                "id2": "cc748",
                "type": "solid",
                "endArrow": "arrow",
                "thickness": 1,
                "startX": 1,
                "startY": 0,
                "endX": -1,
                "endY": 0
            },
            {
                "graphid": "b50f4",
                "zorder": "32891",
                "point": [
                    {
                        "x": "348.11737386613333",
                        "y": "717.2622721705558",
                        "graphref": "aff39",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "347.598290760959",
                        "y": "1156.9286050374972",
                        "graphref": "b02c7",
                        "relx": "0.0",
                        "rely": "-1.0",
                        "arrowhead": "Arrow"
                    }
                ],
                "nodeName": "interaction",
                "id1": "aff39",
                "id2": "fff69",
                "type": "solid",
                "endArrow": "arrow",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1
            },
            {
                "graphid": "c5133",
                "connectortype": "Elbow",
                "zorder": "32893",
                "point": [
                    {
                        "x": "878.711538461539",
                        "y": "468.79487179487234",
                        "graphref": "ce682",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "769.1268935866387",
                        "y": "493.6520146520153"
                    },
                    {
                        "x": "659.5422487117385",
                        "y": "526.8279629974546",
                        "graphref": "b6702",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "ce682",
                "id2": "b6702",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        878.7,
                        468.8
                    ],
                    [
                        878.7,
                        493.7
                    ],
                    [
                        659.5,
                        493.7
                    ],
                    [
                        659.5,
                        526.8
                    ]
                ]
            },
            {
                "graphid": "c63e4",
                "connectortype": "Elbow",
                "zorder": "32895",
                "point": [
                    {
                        "x": "498.46153846153925",
                        "y": "383.7948717948722",
                        "graphref": "d4612",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "443.7115384615392",
                        "y": "443.29487179487234",
                        "graphref": "ea6de",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d4612",
                "id2": "ea6de",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        498.5,
                        383.8
                    ],
                    [
                        498.5,
                        403.8
                    ],
                    [
                        443.7,
                        403.8
                    ],
                    [
                        443.7,
                        443.3
                    ]
                ]
            },
            {
                "graphid": "faa10",
                "zorder": "32899",
                "point": [
                    {
                        "x": "538.2261590764999",
                        "y": "452.29487179487234",
                        "graphref": "d7534",
                        "relx": "1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "552.0700384615386",
                        "y": "453.04487179487234",
                        "graphref": "e5386",
                        "relx": "-1.0",
                        "rely": "0.0",
                        "arrowhead": "Arrow"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d7534",
                "id2": "e5386",
                "type": "solid",
                "endArrow": "arrow",
                "thickness": 1,
                "startX": 1,
                "startY": 0,
                "endX": -1,
                "endY": 0
            },
            {
                "graphid": "ec99b",
                "connectortype": "Elbow",
                "zorder": "32901",
                "point": [
                    {
                        "x": "308.11737386613333",
                        "y": "707.2622721705558",
                        "graphref": "aff39",
                        "relx": "-1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "300.2055644855511",
                        "y": "736.8255703387243",
                        "graphref": "c6375",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "aff39",
                "id2": "c6375",
                "type": "solid",
                "thickness": 1,
                "startX": -1,
                "startY": 0,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        308.1,
                        707.3
                    ],
                    [
                        300.2,
                        707.3
                    ],
                    [
                        300.2,
                        736.8
                    ]
                ]
            },
            {
                "graphid": "b5fd3",
                "connectortype": "Elbow",
                "zorder": "32903",
                "point": [
                    {
                        "x": "765.5683371903531",
                        "y": "632.71970300956",
                        "graphref": "f3648",
                        "relx": "-0.5",
                        "rely": "1.0"
                    },
                    {
                        "x": "733.2684853188846",
                        "y": "741.85503063324",
                        "graphref": "deef9",
                        "relx": "1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "f3648",
                "id2": "deef9",
                "type": "solid",
                "thickness": 1,
                "startX": -0.5,
                "startY": 1,
                "endX": 1,
                "endY": 0,
                "elbows": [
                    [
                        765.6,
                        632.7
                    ],
                    [
                        765.6,
                        741.9
                    ],
                    [
                        733.3,
                        741.9
                    ]
                ]
            },
            {
                "graphid": "e2178",
                "connectortype": "Elbow",
                "zorder": "32905",
                "point": [
                    {
                        "x": "353.9615384615389",
                        "y": "383.7948717948722",
                        "graphref": "f309d",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "274.4615384615389",
                        "y": "431.97998976220435",
                        "graphref": "eedc0",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "f309d",
                "id2": "eedc0",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        354,
                        383.8
                    ],
                    [
                        354,
                        403.8
                    ],
                    [
                        274.5,
                        403.8
                    ],
                    [
                        274.5,
                        432
                    ]
                ]
            },
            {
                "graphid": "c3c34",
                "connectortype": "Elbow",
                "zorder": "32907",
                "point": [
                    {
                        "x": "590.3283432637979",
                        "y": "1221.9509668866845",
                        "graphref": "f28a2",
                        "relx": "1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "700.551904068885",
                        "y": "1149.5661853188833",
                        "graphref": "efb4d",
                        "relx": "-1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "a5cab",
                "id2": "efb4d",
                "type": "solid",
                "thickness": 1,
                "startX": 1,
                "startY": 0,
                "endX": -1,
                "endY": 0,
                "elbows": [
                    [
                        590.3,
                        1222
                    ],
                    [
                        610.3,
                        1222
                    ],
                    [
                        610.3,
                        1149.6
                    ],
                    [
                        700.6,
                        1149.6
                    ]
                ]
            },
            {
                "graphid": "d2703",
                "connectortype": "Elbow",
                "zorder": "32909",
                "point": [
                    {
                        "x": "383.9869621903526",
                        "y": "546.3372446762253",
                        "graphref": "d8bf5",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "384.157034550747",
                        "y": "586.7476755152276",
                        "graphref": "eb255",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d8bf5",
                "id2": "eb255",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        384,
                        546.3
                    ],
                    [
                        384,
                        566.3
                    ],
                    [
                        384.2,
                        566.3
                    ],
                    [
                        384.2,
                        586.7
                    ]
                ]
            },
            {
                "graphid": "f6e96",
                "zorder": "32911",
                "point": [
                    {
                        "x": "639.5422487117385",
                        "y": "546.8279629974546",
                        "graphref": "b6702",
                        "relx": "-0.5",
                        "rely": "1.0"
                    },
                    {
                        "x": "393.9107367236676",
                        "y": "1156.9286050374972",
                        "graphref": "b02c7",
                        "relx": "0.5",
                        "rely": "-1.0",
                        "arrowhead": "mim-inhibition"
                    }
                ],
                "nodeName": "interaction",
                "id1": "b6702",
                "id2": "fff69",
                "type": "solid",
                "endArrow": "square",
                "thickness": 1,
                "startX": -0.5,
                "startY": 1,
                "endX": 0.5,
                "endY": -1
            },
            {
                "graphid": "b04c3",
                "connectortype": "Elbow",
                "zorder": "32913",
                "point": [
                    {
                        "x": "1156.8507113682629",
                        "y": "829.7822140991225",
                        "graphref": "ca8a4",
                        "relx": "0.5",
                        "rely": "1.0"
                    },
                    {
                        "x": "1128.3930929799067",
                        "y": "880.6703468675306"
                    },
                    {
                        "x": "1099.9354745915502",
                        "y": "905.2941159369761",
                        "graphref": "a19ab",
                        "relx": "0.5",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "ca8a4",
                "id2": "daaa7",
                "type": "solid",
                "thickness": 1,
                "startX": 0.5,
                "startY": 1,
                "endX": 0.5,
                "endY": -1,
                "elbows": [
                    [
                        1156.9,
                        829.8
                    ],
                    [
                        1156.9,
                        880.7
                    ],
                    [
                        1099.9,
                        880.7
                    ],
                    [
                        1099.9,
                        905.3
                    ]
                ]
            },
            {
                "graphid": "b17fb",
                "connectortype": "Elbow",
                "zorder": "32915",
                "point": [
                    {
                        "x": "1237.8343621332983",
                        "y": "1281.322910538387",
                        "graphref": "b16c1",
                        "relx": "0.0",
                        "rely": "-1.0"
                    },
                    {
                        "x": "1318.5725790454585",
                        "y": "1241.1221236261197",
                        "graphref": "c28e9",
                        "relx": "-1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "b16c1",
                "id2": "b8425",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": -1,
                "endX": -1,
                "endY": 0,
                "elbows": [
                    [
                        1237.8,
                        1281.3
                    ],
                    [
                        1237.8,
                        1241.1
                    ],
                    [
                        1318.6,
                        1241.1
                    ]
                ]
            },
            {
                "graphid": "bd8c4",
                "groupref": "daaa7",
                "zorder": "32917",
                "point": [
                    {
                        "x": "1013.7343365744518",
                        "y": "1037.7317413181195",
                        "graphref": "d8e39",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "1012.9838289072609",
                        "y": "1092.140038542295",
                        "graphref": "ff8cd",
                        "relx": "0.0",
                        "rely": "-1.0",
                        "arrowhead": "TBar"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d8e39",
                "id2": "ff8cd",
                "type": "solid",
                "endArrow": "square",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1
            },
            {
                "graphid": "b8528",
                "connectortype": "Elbow",
                "zorder": "32919",
                "point": [
                    {
                        "x": "498.46153846153925",
                        "y": "383.7948717948722",
                        "graphref": "d4612",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "603.8200384615386",
                        "y": "432.29487179487234",
                        "graphref": "e5386",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d4612",
                "id2": "e5386",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        498.5,
                        383.8
                    ],
                    [
                        498.5,
                        403.8
                    ],
                    [
                        603.8,
                        403.8
                    ],
                    [
                        603.8,
                        432.3
                    ]
                ]
            },
            {
                "graphid": "d2ead",
                "connectortype": "Elbow",
                "zorder": "32921",
                "point": [
                    {
                        "x": "403.4693060695241",
                        "y": "606.7476755152276",
                        "graphref": "eb255",
                        "relx": "0.5",
                        "rely": "1.0"
                    },
                    {
                        "x": "430.9579933815353",
                        "y": "697.7951995687878",
                        "graphref": "c9ae1",
                        "relx": "-1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "eb255",
                "id2": "db3f5",
                "type": "solid",
                "thickness": 1,
                "startX": 0.5,
                "startY": 1,
                "endX": -1,
                "endY": 0,
                "elbows": [
                    [
                        403.5,
                        606.7
                    ],
                    [
                        403.5,
                        697.8
                    ],
                    [
                        431,
                        697.8
                    ]
                ]
            },
            {
                "graphid": "e6ae4",
                "zorder": "32923",
                "point": [
                    {
                        "x": "242.4615384615389",
                        "y": "443.97998976220435",
                        "graphref": "eedc0",
                        "relx": "-1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "213.46153846153854",
                        "y": "442.6686794605929",
                        "graphref": "ea180",
                        "relx": "1.0",
                        "rely": "0.0",
                        "arrowhead": "Arrow"
                    }
                ],
                "nodeName": "interaction",
                "id1": "eedc0",
                "id2": "a4d4a",
                "type": "solid",
                "endArrow": "arrow",
                "thickness": 1,
                "startX": -1,
                "startY": 0,
                "endX": 1,
                "endY": 0
            },
            {
                "graphid": "a56af",
                "connectortype": "Elbow",
                "zorder": "32925",
                "point": [
                    {
                        "x": "1176.8507113682629",
                        "y": "819.7822140991225",
                        "graphref": "ca8a4",
                        "relx": "1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "1212.5166052427894",
                        "y": "847.6900423143429"
                    },
                    {
                        "x": "1250.2368292259966",
                        "y": "875.5978705295635",
                        "graphref": "d0c59",
                        "relx": "-1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "ca8a4",
                "id2": "d0c59",
                "type": "solid",
                "thickness": 1,
                "startX": 1,
                "startY": 0,
                "endX": -1,
                "endY": 0,
                "elbows": [
                    [
                        1176.9,
                        819.8
                    ],
                    [
                        1212.5,
                        819.8
                    ],
                    [
                        1212.5,
                        875.6
                    ],
                    [
                        1250.2,
                        875.6
                    ]
                ]
            },
            {
                "graphid": "bde3a",
                "connectortype": "Elbow",
                "zorder": "32927",
                "point": [
                    {
                        "x": "1248.5834174010513",
                        "y": "1139.4440001987116",
                        "graphref": "d01e0",
                        "relx": "-1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "1187.6704519158134",
                        "y": "1089.729541985328",
                        "graphref": "bf0e6",
                        "relx": "1.0",
                        "rely": "0.5"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d01e0",
                "id2": "bf0e6",
                "type": "solid",
                "thickness": 1,
                "startX": -1,
                "startY": 0,
                "endX": 1,
                "endY": 0.5,
                "elbows": [
                    [
                        1248.6,
                        1139.4
                    ],
                    [
                        1228.6,
                        1139.4
                    ],
                    [
                        1228.6,
                        1089.7
                    ],
                    [
                        1187.7,
                        1089.7
                    ]
                ]
            },
            {
                "graphid": "c73cc",
                "zorder": "32929",
                "point": [
                    {
                        "x": "382.7115384615392",
                        "y": "464.79487179487234",
                        "graphref": "eddfc",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "383.9869621903526",
                        "y": "526.3372446762253",
                        "graphref": "d8bf5",
                        "relx": "0.0",
                        "rely": "-1.0",
                        "arrowhead": "Arrow"
                    }
                ],
                "nodeName": "interaction",
                "id1": "eddfc",
                "id2": "d8bf5",
                "type": "solid",
                "endArrow": "arrow",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1
            },
            {
                "graphid": "d5a2d",
                "connectortype": "Elbow",
                "zorder": "32931",
                "point": [
                    {
                        "x": "384.157034550747",
                        "y": "606.7476755152276",
                        "graphref": "eb255",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "366.13720420844015",
                        "y": "660.1282051282058"
                    },
                    {
                        "x": "348.11737386613333",
                        "y": "697.2622721705558",
                        "graphref": "aff39",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "eb255",
                "id2": "aff39",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        384.2,
                        606.7
                    ],
                    [
                        384.2,
                        660.1
                    ],
                    [
                        348.1,
                        660.1
                    ],
                    [
                        348.1,
                        697.3
                    ]
                ]
            },
            {
                "graphid": "aaa57",
                "connectortype": "Elbow",
                "zorder": "32933",
                "point": [
                    {
                        "x": "353.9615384615389",
                        "y": "383.7948717948722",
                        "graphref": "f309d",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "173.71153846153854",
                        "y": "430.29487179487234",
                        "graphref": "cc38a",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "f309d",
                "id2": "cc38a",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        354,
                        383.8
                    ],
                    [
                        354,
                        403.8
                    ],
                    [
                        173.7,
                        403.8
                    ],
                    [
                        173.7,
                        430.3
                    ]
                ]
            },
            {
                "graphid": "a53ad",
                "connectortype": "Elbow",
                "zorder": "32935",
                "point": [
                    {
                        "x": "1288.5834174010513",
                        "y": "1149.4440001987116",
                        "graphref": "d01e0",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "788.4615384615395",
                        "y": "1212.756479105188",
                        "graphref": "c0f16",
                        "relx": "1.0",
                        "rely": "0.5"
                    }
                ],
                "nodeName": "interaction",
                "id1": "d01e0",
                "id2": "c0f16",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": 1,
                "endY": 0.5,
                "elbows": [
                    [
                        1288.6,
                        1149.4
                    ],
                    [
                        1288.6,
                        1212.8
                    ],
                    [
                        788.5,
                        1212.8
                    ]
                ]
            },
            {
                "graphid": "f4f23",
                "connectortype": "Elbow",
                "zorder": "32961",
                "point": [
                    {
                        "x": "1096.8507113682629",
                        "y": "819.7822140991225",
                        "graphref": "ca8a4",
                        "relx": "-1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "754.2130397306084",
                        "y": "888.8747712501753",
                        "graphref": "a1c46",
                        "relx": "1.0",
                        "rely": "0.5"
                    }
                ],
                "nodeName": "interaction",
                "id1": "ca8a4",
                "id2": "e2ca2",
                "type": "solid",
                "thickness": 1,
                "startX": -1,
                "startY": 0,
                "endX": 1,
                "endY": 0.5,
                "elbows": [
                    [
                        1096.9,
                        819.8
                    ],
                    [
                        1076.9,
                        819.8
                    ],
                    [
                        1076.9,
                        888.9
                    ],
                    [
                        754.2,
                        888.9
                    ]
                ]
            },
            {
                "graphid": "bd157",
                "connectortype": "Elbow",
                "zorder": "33219",
                "point": [
                    {
                        "x": "785.5683371903531",
                        "y": "632.71970300956",
                        "graphref": "f3648",
                        "relx": "0.0",
                        "rely": "1.0"
                    },
                    {
                        "x": "841.7229787332676",
                        "y": "1009.3310196549803",
                        "graphref": "db804",
                        "relx": "-1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "f3648",
                "id2": "db804",
                "type": "solid",
                "thickness": 1,
                "startX": 0,
                "startY": 1,
                "endX": -1,
                "endY": 0,
                "elbows": [
                    [
                        785.6,
                        632.7
                    ],
                    [
                        785.6,
                        1009.3
                    ],
                    [
                        841.7,
                        1009.3
                    ]
                ]
            },
            {
                "graphid": "fb180",
                "connectortype": "Elbow",
                "zorder": "33221",
                "point": [
                    {
                        "x": "403.4693060695241",
                        "y": "606.7476755152276",
                        "graphref": "eb255",
                        "relx": "0.5",
                        "rely": "1.0"
                    },
                    {
                        "x": "841.7229787332676",
                        "y": "1029.945287652028",
                        "graphref": "c74c5",
                        "relx": "-1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "eb255",
                "id2": "c74c5",
                "type": "solid",
                "thickness": 1,
                "startX": 0.5,
                "startY": 1,
                "endX": -1,
                "endY": 0,
                "elbows": [
                    [
                        403.5,
                        606.7
                    ],
                    [
                        403.5,
                        1029.9
                    ],
                    [
                        841.7,
                        1029.9
                    ]
                ]
            },
            {
                "graphid": "a256e",
                "groupref": "daaa7",
                "connectortype": "Elbow",
                "zorder": "33223",
                "point": [
                    {
                        "x": "921.5651538329671",
                        "y": "988.7167516579328",
                        "graphref": "bfcf5",
                        "relx": "1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "1013.7343365744518",
                        "y": "1017.7317413181195",
                        "graphref": "d8e39",
                        "relx": "0.0",
                        "rely": "-1.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "bfcf5",
                "id2": "d8e39",
                "type": "solid",
                "thickness": 1,
                "startX": 1,
                "startY": 0,
                "endX": 0,
                "endY": -1,
                "elbows": [
                    [
                        921.6,
                        988.7
                    ],
                    [
                        1013.7,
                        988.7
                    ],
                    [
                        1013.7,
                        1017.7
                    ]
                ]
            },
            {
                "graphid": "bd47c",
                "connectortype": "Elbow",
                "zorder": "33227",
                "point": [
                    {
                        "x": "308.11737386613333",
                        "y": "707.2622721705558",
                        "graphref": "aff39",
                        "relx": "-1.0",
                        "rely": "0.0"
                    },
                    {
                        "x": "239.11262110298992",
                        "y": "707.1834048260207",
                        "graphref": "fb9d6",
                        "relx": "1.0",
                        "rely": "0.0"
                    }
                ],
                "nodeName": "interaction",
                "id1": "aff39",
                "id2": "fb9d6",
                "type": "solid",
                "thickness": 1,
                "startX": -1,
                "startY": 0,
                "endX": 1,
                "endY": 0,
                "elbows": [
                    [
                        308.1,
                        707.3
                    ],
                    [
                        288.1,
                        707.3
                    ],
                    [
                        288.1,
                        707.2
                    ],
                    [
                        239.1,
                        707.2
                    ]
                ]
            }
        ],
        "nodeIndices": {
            "fff69": 0,
            "f3cd6": 1,
            "ce48b": 2,
            "b16c1": 3,
            "e8c6b": 4,
            "f3a24": 5,
            "e2ca2": 6,
            "aef45": 7,
            "bc57d": 8,
            "c0f16": 9,
            "e1c3b": 10,
            "ed541": 11,
            "a83c9": 12,
            "e0f0a": 13,
            "d318a": 14,
            "d8be9": 15,
            "bea67": 16,
            "f358b": 17,
            "adca6": 18,
            "daaa7": 19,
            "bf0e6": 20,
            "db3f5": 21,
            "f8281": 22,
            "e7c4b": 23,
            "b8cf6": 24,
            "a260c": 25,
            "ec186": 26,
            "b68bb": 27,
            "a268b": 28,
            "ebdf3": 29,
            "c63cd": 30,
            "e197c": 31,
            "a6a27": 32,
            "b4e72": 33,
            "f6699": 34,
            "f806d": 35,
            "e136b": 36,
            "cb3c3": 37,
            "fa302": 38,
            "a9abb": 39,
            "bef61": 40,
            "d558e": 41,
            "dd82c": 42,
            "e56b9": 43,
            "e94a1": 44,
            "eb476": 45,
            "efbce": 46,
            "f0ff8": 47,
            "fb826": 48,
            "fe1d5": 49,
            "dae5b": 50,
            "ef6c1": 51,
            "be2d9": 52,
            "c8f9f": 53,
            "dacce": 54,
            "db2ca": 55,
            "f0ad6": 56,
            "db6dc": 57,
            "c358b": 58,
            "b717b": 59,
            "b6a45": 60,
            "b666e": 61,
            "ff8cd": 62,
            "c700d": 63,
            "f437b": 64,
            "dfe74": 65,
            "c51a3": 66,
            "d69c6": 67,
            "de9f1": 68,
            "b1aab": 69,
            "b8425": 70,
            "ebfaf": 71,
            "df74c": 72,
            "d9cec": 73,
            "d3f8d": 74,
            "b2b69": 75,
            "ce679": 76,
            "bda4a": 77,
            "ffc83": 78,
            "ee465": 79,
            "c5ee0": 80,
            "d16dc": 81,
            "a37d8": 82,
            "ae333": 83,
            "f309d": 84,
            "fd6d4": 85,
            "e3a94": 86,
            "d4612": 87,
            "e40a8": 88,
            "cbcb5": 89,
            "fb58a": 90,
            "a19cc": 91,
            "ab70b": 92,
            "ec97b": 93,
            "cf98e": 94,
            "c9df5": 95,
            "d01e4": 96,
            "d1e20": 97,
            "d3a67": 98,
            "e6d9c": 99,
            "edbb6": 100,
            "b3f1d": 101,
            "db804": 102,
            "aff39": 103,
            "fde8e": 104,
            "f76b2": 105,
            "a132b": 106,
            "c6f3d": 107,
            "ecb8e": 108,
            "a3a34": 109,
            "cc748": 110,
            "d8e39": 111,
            "d01e0": 112,
            "ee899": 113,
            "d8bf5": 114,
            "f2f91": 115,
            "f813c": 116,
            "a5cb6": 117,
            "f8565": 118,
            "f8634": 119,
            "f52e2": 120,
            "baeff": 121,
            "eb9d3": 122,
            "b0bbb": 123,
            "ce682": 124,
            "a5cab": 125,
            "eb3c0": 126,
            "c2f1d": 127,
            "d8794": 128,
            "bc89e": 129,
            "a283d": 130,
            "dbdee": 131,
            "fb9d6": 132,
            "d5b1a": 133,
            "bb3bc": 134,
            "b6702": 135,
            "e39b2": 136,
            "bfcf5": 137,
            "deef9": 138,
            "ea6de": 139,
            "d0320": 140,
            "f7c0c": 141,
            "a52cb": 142,
            "bae9c": 143,
            "e1dca": 144,
            "d91aa": 145,
            "b9166": 146,
            "f7a22": 147,
            "d8fb3": 148,
            "f7c1d": 149,
            "eddfc": 150,
            "fada0": 151,
            "c98db": 152,
            "d375c": 153,
            "f3648": 154,
            "df04d": 155,
            "bee91": 156,
            "f0f62": 157,
            "d31d4": 158,
            "b96f2": 159,
            "ca8a4": 160,
            "fb0bc": 161,
            "ae474": 162,
            "a4d4a": 163,
            "cc38a": 164,
            "eb6f5": 165,
            "efb4d": 166,
            "d7cbe": 167,
            "f95b1": 168,
            "dfac1": 169,
            "b835e": 170,
            "cdc29": 171,
            "d0c59": 172,
            "c74c5": 173,
            "c6375": 174,
            "b9253": 175,
            "e1607": 176,
            "eb255": 177,
            "d12de": 178,
            "eedc0": 179,
            "bfca5": 180,
            "fcf77": 181,
            "a81f8": 182,
            "d7534": 183,
            "cb74d": 184,
            "e6fda": 185,
            "c0bc5": 186,
            "e5386": 187,
            "cd2e5": 188,
            "d37a4": 189,
            "f8ed1": 190,
            "ca941": 191,
            "b6351": 192,
            "c5c8c": 193,
            "f900c": 194,
            "bf6c8": 195,
            "b823a": 196,
            "d9434": 197,
            "e5051": 198,
            "b5376": 199,
            "f032d": 200,
            "b003d": 201,
            "ed142": 202,
            "e508c": 203,
            "e5ae2": 204,
            "f6f3b": 205,
            "dcf46": 206,
            "ee82d": 207,
            "eced8": 208,
            "df75e": 209,
            "c8e45": 210,
            "c0b1d": 211,
            "e608e": 212,
            "b0d50": 213
        }
    },
    config={
        "adjustBezier": False,
        "graphType": "Network",
        "calculateLayout": False,
        "showAnimation": False,
        "networkNodesOnTop": False,
        "showNodeNameThreshold": 20000,
        "networkFreeze": False,
        "preScaleNetwork": False,
        "title": "Lung fibrosis",
        "networkVendor": "Wikipathways",
        "skipRender": False
    },
    width=613,
    height=613,
    events=CXEvents(),
    after_render=[],
    other_init_params={
        "version": 35,
        "events": False,
        "info": False,
        "afterRenderInit": False,
        "noValidate": True
    }
)

display = CXNoteBook(cx) 
display.render(output_file="network_11.html")
